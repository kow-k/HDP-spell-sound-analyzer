# %% [markdown]
# # 分散的に表現された terms をまとめる
# # string2string パッケージを使用

# %%
## run the following to install string2string package if neccessary
#!pip install -U string2string
## run the following if string2string needs it
#!pip install -U ipywidgets

# %%
import sys, os, re
import pandas as pd
import ast

# %%
## settings
verbose           = False
## term
term_classes      = [ 'spell', 'sound' ]
term_class        = term_classes[0]
n_for_ngram       = 4
ngram_is_skippy   = True
if ngram_is_skippy:
    term_type     = f"skippy{n_for_ngram}gram"
else:
    term_type     = f"{n_for_ngram}gram"
if term_class == 'sound':
    term_type = "sn_" + term_type
else:
    term_type = "sp_" + term_type
print(f"term_type: {term_type}")

## gap mark
gap_mark          = "…"
print(f"gap_mark: {gap_mark}")

## accent handling
suppress_accents   = True
if term_class == 'sound':
    if suppress_accents:
        accent_status = "-unaccented"
    else:
        accent_stratus = "-accented"
else:
    accent_status = ""
print(f"accent_status: {accent_status}")
# Out:
# term_type: sp_skippy4gram
# gap_mark: …
# accent_status:

# %%
## target language
## a key must be part of a file name 
target_lang_dict = {    'en_US' : 'English (US)',
                        'en_UK' : 'English (UK)',
                        'en_N_only' : 'English noun (WN)',
                        'en_V_only' : 'English verb (WN)',
                        'en_A_only' : 'English adj (WN)',
                        'en_R_only' : 'English adv (WN)',
                        'ar'    : 'Arabic',
                        'de'    : 'German',
                        'de_N_only' : 'German Nouns',
                        'de_non_N_only' : 'German Non-nouns',
                        'eo'    : 'Esperanto',
                        'es_ES' : 'Spanish (Spain)',
                        'es_MX' : 'Spanish (Mexico)',
                        'fi'    : 'Finnish',
                        'fr_FR' : 'French (France)',
                        'fr_QC' : 'French (Quebec)',
                        'is'    : 'Icelandic',
                        'ir'    : 'Irish',
                        'nl'    : 'Dutch',
                        'ro'    : 'Romanian',
                        'sw'    : 'Swahili' }
## proper language selection
target_lang_keys = [    'en_US', # 0
                        'en_UK', # 1
                        'en_N_only', # 2
                        'en_V_only', # 3
                        'en_A_only', # 4
                        'en_R_only', # 5
                        'ar', # 6
                        'de', # 7
                        'de_N_only', # 8
                        'de_non_N_only', # 9
                        'eo', 'es_ES', 'es_MX',
                        'fi', 'fr_FR', 'fr_QC',
                        'is', 'nl', 'ro', 'sw',
                        'ir' # This lacks sound
                    ]
## check
target_lang_key  = target_lang_keys[4]
print(f"target_lang_key: {target_lang_key}")
print(f"target lang: {target_lang_dict[target_lang_key]} [{target_lang_key}]")
## target_attr [effective only for Irish]
target_class = ""
#target_class = None # This causes an unrediable error
if target_lang_key == "ir":
    target_classes = [ 'adjectives', 'nouns', 'verbs' ]
    target_class = f"-{target_classes[3]}"
print(f"target_class: {target_class}")
lang_dir_name = target_lang_dict[target_lang_key].split()[0]
print(f"lang_dir_name: {lang_dir_name}")
# Out:
# target_lang_key: en_A_only
# target lang: English adj (WN) [en_A_only]
# target_class:
# lang_dir_name: English

# %%
## read data from a file
import pandas as pd
import ast
##
max_n_topics = 45
##
use_sample = True
if use_sample:
    #data_file = f"results/terms-by-topics-raw/samples/hdp{max_n_topics}_topics_raw.csv"
    data_file = f"results/terms-by-topics-raw/English/English-pair-topics90-sp_5gram-sn_5gram-unaccented.csv"
else:
    data_file = f"results/terms-by-topics-raw/{lang_dir_name}/{target_lang_dict[target_lang_key]}{target_class}-topics{max_n_topics}-{term_type}{accent_status}.csv"
print(data_file)

## read a file and evaluate its content
raw_df = pd.read_csv(data_file, header = None)
for col in raw_df:
    raw_df[col] = raw_df[col].apply(ast.literal_eval) # evaluation is crucial
##
raw_df
# Out:
# results/terms-by-topics-raw/English/English-pair-topics90-sp_5gram-sn_5gram-unaccented.csv
#                                          0   \
# 0      (#gal :: #ɡəɫ, 0.004248156812815527)
# 1    (erman :: tɝmə, 0.0032761726425191108)
# 2    (owski :: ski#, 0.0032534475311765615)
# 3     (#non :: #nɑnf, 0.003218828760648162)
# 4     (utche :: tʃɝ#, 0.003214399682457863)
# ..                                      ...
# 115   (mela :: #mɛɫ, 0.0015885525108991346)
# 116   (life :: #ɫaɪ, 0.0015813560486005285)
# 117  (ski# :: nski#, 0.0015777935119456025)
# 118   (ler# :: eɪɫɝ, 0.0015746788961115816)
# 119    (lect :: ɫɛkt, 0.001563560335746395)
#
#                                           1   \
# 0      (gton# :: ɪŋtə, 0.004291690380586001)
# 1     (#ligh :: #ɫaɪt, 0.003862912175634734)
# 2      (owsk :: ski#, 0.0035130428791565874)
# 3        (ted# :: stɪd, 0.00348225088567199)
# 4       (#ent :: #ɛnɝ, 0.003356694588500677)
# ..                                       ...
# 115    (ders :: ændɝ, 0.0015494075000850567)
# 116    (elin :: ɫɪn#, 0.0015459198528562515)
# 117  (#barb :: #bɑɹb, 0.0015419606173942204)
# 118  (lers# :: əɫɝz#, 0.0015363990264261396)
# 119  (amtra :: æmtɹæ, 0.0015312545994087422)
#
#                                          2   \
# 0     (land :: #ɫænd, 0.004342214301990682)
# 1    (enin :: ənɪŋ#, 0.0034972856783785596)
# 2    (erman :: ɝmən#, 0.003424881241823422)
# 3     (ned# :: ənd#, 0.0032949913338566695)
# 4      (ngs# :: ɫɪŋz, 0.003275517980179494)
# ..                                      ...
# 115   (#tom :: #toʊm, 0.001582410010961876)
# 116   (#ran :: #ɹæns, 0.001581059077192023)
# 117  (terma :: ɝmən, 0.0015808665287902447)
# 118   (ley# :: tɫi#, 0.0015806566824827116)
# 119  (ites :: aɪts#, 0.0015805802440594752)
#
#                                          3   \
# 0      (carb :: #kɑɹ, 0.004061346962031881)
# 1     (stry# :: tɹi#, 0.004052233440539947)
# 2      (#gra :: #ɡɹæ, 0.003982225838663347)
# 3     (ling# :: əɫɪŋ, 0.003622674870936606)
# 4     (ping# :: pɪŋ#, 0.003573835190723687)
# ..                                      ...
# 115    (#tra :: #tɹe, 0.001554274235956147)
# 116  (line :: ɫaɪn#, 0.0015525203441251495)
# 117   (nter :: #ɛnɝ, 0.0015417766845582973)
# 118  (rman# :: mən#, 0.0015396998992542631)
# 119   (evit :: ɛvɪt, 0.0015332719518631644)
#
#                                          4   \
# 0       (tock :: stɑk, 0.00441558156620048)
# 1        (kman :: kmən, 0.0040961140819052)
# 2     (oman :: oʊmə, 0.0035972365595806502)
# 3    (derma :: ɝmən, 0.0034899171942140146)
# 4     (ide# :: aɪd#, 0.0034172266039369163)
# ..                                      ...
# 115  (ting :: ɪtɪŋ#, 0.0015239252527665128)
# 116  (erton :: ɝtən, 0.0015225340011310801)
# 117   (ess# :: tɫəs, 0.0015177972731723552)
# 118  (dness :: dnəs, 0.0015051488447477186)
# 119   (term :: tɝmə, 0.0015015645459486079)
#
#                                          5   \
# 0      (ble# :: bəɫ#, 0.005563951476536451)
# 1      (ingt :: ɪŋtə, 0.003620751695214526)
# 2    (erlin :: ɝɫɪn, 0.0031587023466216006)
# 3     (#lig :: #ɫaɪ, 0.0030363359529131553)
# 4      (#lif :: ɫaɪf, 0.002940242966582451)
# ..                                      ...
# 115  (#mark :: #mɑɹ, 0.0014991696824870628)
# 116  (hart# :: hɑɹt#, 0.001497246871261972)
# 117   (mccu :: #mək, 0.0014942399020303366)
# 118   (ood# :: wʊd#, 0.0014926566450153107)
# 119   (#chit :: tʃɪt, 0.001481319106801145)
#
#                                           6   \
# 0       (#van :: #væn, 0.003759224453624997)
# 1     (#over :: oʊvɝ, 0.0037423630819394087)
# 2        (#mel :: #mɛɫ, 0.00372423802351194)
# 3      (righ :: ɹaɪt#, 0.003275270860145393)
# 4    (#ligh :: #ɫaɪt, 0.0030794745176119993)
# ..                                       ...
# 115    (nzo# :: zoʊ#, 0.0015142138381897534)
# 116   (nick# :: nɪk#, 0.0015088853424979516)
# 117    (boar :: bɔɹd, 0.0015031096146692494)
# 118     (#rad :: #ɹæd, 0.001502131453357985)
# 119   (derm :: dɝmən, 0.0015001122851729485)
#
#                                          7   \
# 0     (line# :: aɪn#, 0.005076014379245686)
# 1     (amtra :: mtɹæ, 0.005051521402055748)
# 2     (nsky :: nski, 0.0039700117434851336)
# 3      (derm :: mən#, 0.003594761103043637)
# 4      (ande :: #vænd, 0.00358300723372953)
# ..                                      ...
# 115   (ser# :: ɪsɝ#, 0.0015812481215197137)
# 116    (etti :: ɛti#, 0.001578877626064493)
# 117  (right :: ɹaɪt, 0.0015668567467522739)
# 118   (ing# :: #aʊt, 0.0015657369445078986)
# 119  (ters# :: stɝz#, 0.001563577832655399)
#
#                                          8   \
# 0       (eck# :: bɛk#, 0.00373008329555262)
# 1     (#far :: #fɑɹ, 0.0036475522155502123)
# 2    (rrow# :: ɹoʊ#, 0.0032662952524186405)
# 3    (flan :: #fɫæn, 0.0032178975555614405)
# 4      (flan :: #fɫæ, 0.003159939586298707)
# ..                                      ...
# 115  (chey# :: tʃi#, 0.0015672882928895382)
# 116   (shin :: ʃɪŋ#, 0.0015475289813329078)
# 117   (ler# :: sɫɝ#, 0.0015443420828485236)
# 118    (nski :: ski#, 0.001539849778796551)
# 119   (stam :: stæm, 0.0015395991889066067)
#
#                                          9   ...  \
# 0      (odge :: ɫɑdʒ, 0.004731948599928874)  ...
# 1     (#mai :: #meɪ, 0.0044755413224138434)  ...
# 2     (ence# :: əns#, 0.003912906271680249)  ...
# 3     (#galo :: #ɡəɫ, 0.003307218641964862)  ...
# 4    (#home :: #hoʊ, 0.0032044035703892183)  ...
# ..                                      ...  ...
# 115  (ridge :: ɪdʒ#, 0.0015140596124008018)  ...
# 116   (ding :: dɪŋ#, 0.0015078765259744463)  ...
# 117   (iff# :: ɫɪf#, 0.0015035140950261595)  ...
# 118   (#car :: #kɑɹb, 0.001503373019721552)  ...
# 119  (tes# :: aɪts#, 0.0014944620326020868)  ...
#
#                                          80  \
# 0    (ling# :: ɫɪŋ#, 0.0036955379675354233)
# 1     (ranc :: æns#, 0.0035013575593613486)
# 2      (#fre :: #fɹɛ, 0.003068433830260731)
# 3     (#mcn :: məkn, 0.0030357677589957755)
# 4     (ley# :: sɫi#, 0.0030033358217822588)
# ..                                      ...
# 115  (#bric :: #bɹɪ, 0.0015665149386007644)
# 116  (nds# :: ɫəndz, 0.0015619316142505078)
# 117   (#bri :: #bɹa, 0.0015611512272136166)
# 118  (#home :: hoʊm, 0.0015484658530254324)
# 119  (ers# :: əɫɝz#, 0.0015471271575577328)
#
#                                          81  \
# 0     (ille# :: vɪɫ#, 0.004282078839442345)
# 1      (tal# :: təɫ#, 0.004030772258205348)
# 2     (#gin :: #ɡɪn, 0.0036286063484179776)
# 3     (#amt :: tɹæk, 0.0034246137229986596)
# 4     (#whi :: #hwɪ, 0.0030609085424518965)
# ..                                      ...
# 115   (erto :: tən#, 0.0015140051393613225)
# 116   (ina# :: inə#, 0.0015032929229885491)
# 117   (rst# :: ɝst#, 0.0014924553364928164)
# 118  (elin :: ɪɫɪn#, 0.0014911827678547472)
# 119  (#gol :: #ɡoʊɫ, 0.0014897936588136288)
#
#                                          82  \
# 0      (erin :: ɝɪŋ#, 0.005185234375393777)
# 1    (atter :: ætɝ#, 0.0037860304054055318)
# 2     (#sto :: stɔɹ, 0.0037161256396394025)
# 3    (#beac :: #bit, 0.0036816270992873403)
# 4      (ick# :: wɪk#, 0.003517768511614072)
# ..                                      ...
# 115  (rship :: ʃɪp#, 0.0015265964206202212)
# 116   (beac :: bitʃ, 0.0015242666139431923)
# 117     (kel# :: ɪkəɫ, 0.00151987362451577)
# 118  (rton :: ɹtənz, 0.0015179277385475938)
# 119  (insk :: nski#, 0.0015054727951234073)
#
#                                           83  \
# 0         (oman :: oʊmə, 0.0059112803042083)
# 1       (vand :: vænd, 0.004355830836093759)
# 2     (annon :: ænən, 0.0033279224225545422)
# 3      (are# :: wɛɹ#, 0.0030018324767827373)
# 4     (#vand :: #væn, 0.0030001421144081938)
# ..                                       ...
# 115    (ansk :: ski#, 0.0015470621634459205)
# 116    (ansk :: ænsk, 0.0015434892342061938)
# 117    (#rot :: #ɹoʊ, 0.0015421473952079738)
# 118    (rton :: ɹtən, 0.0015334645249710473)
# 119  (#cass :: #kæsə, 0.0015259241117234902)
#
#                                          84  \
# 0    (#mess :: #mɛs, 0.0040403060957354625)
# 1      (utch :: kətʃ, 0.003825879705124558)
# 2    (illin :: ɪɫɪŋ, 0.0032463516785429217)
# 3     (ster :: stɝz#, 0.003176975489670759)
# 4     (rant :: ɝænt, 0.0031700257963251906)
# ..                                      ...
# 115  (ston# :: tən#, 0.0014963066222181021)
# 116   (ters :: stɝz, 0.0014948100650553806)
# 117   (rst# :: ɝst#, 0.0014941625701995623)
# 118  (ashi# :: ɑʃi#, 0.0014938017100956733)
# 119  (ashin :: ʃɪŋ#, 0.0014896395994332113)
#
#                                           85  \
# 0       (nks# :: ŋks#, 0.005103190217820056)
# 1      (ding :: ɪdɪŋ#, 0.003972810242264332)
# 2      (#rep :: #ɹip, 0.0038265393476635944)
# 3       (rd's :: ɑɹdz#, 0.00360101305294283)
# 4     (on's# :: tənz, 0.0031821267440594056)
# ..                                       ...
# 115    (#fen :: #fɛn, 0.0015372368944554305)
# 116  (erson :: ɝsən#, 0.0015358960251562548)
# 117    (#gan :: #ɡæn, 0.0015335954719108192)
# 118    (nski :: ɪnsk, 0.0015311952743720424)
# 119    (#bac :: #bæk, 0.0015289764162576213)
#
#                                           86  \
# 0      (life :: #ɫaɪf, 0.005256599738198006)
# 1       (less :: tɫəs, 0.004591930732290849)
# 2       (art# :: ɪnhɑ, 0.004392788676127281)
# 3      (#par :: #pɛɹə, 0.004116585827694997)
# 4        (ide# :: aɪd#, 0.00378133316494361)
# ..                                       ...
# 115    (#gol :: ɡoʊɫ, 0.0014973853672511307)
# 116  (ites# :: aɪts#, 0.0014970889068128357)
# 117    (ged# :: dʒd#, 0.0014779320298910713)
# 118    (#for :: #fɔɹ, 0.0014768050759806704)
# 119    (mark :: #mɑɹ, 0.0014766653412385045)
#
#                                          87  \
# 0     (ider :: aɪdɝ#, 0.004816085920841073)
# 1     (idge# :: ɪdʒ#, 0.004275297650450445)
# 2      (ord# :: fɝd#, 0.004108505379615207)
# 3      (ship# :: ʃɪp#, 0.00386899489171738)
# 4      (#lan :: ɫænd, 0.003827321658400536)
# ..                                      ...
# 115   (#sna :: #snæ, 0.0015754812186473848)
# 116  (inski :: ɪnsk, 0.0015696451020858952)
# 117   (#sun :: #sən, 0.0015671462854806079)
# 118   (del# :: dəɫ#, 0.0015603017160660375)
# 119   (ansk :: ski#, 0.0015546466188142711)
#
#                                           88  \
# 0      (lings :: ɪŋz#, 0.004245911162598869)
# 1        (ight :: ɫaɪt, 0.00363721160378063)
# 2      (#van :: vænd, 0.0036320409576697664)
# 3       (der# :: ndɝ#, 0.003221218003074198)
# 4       (ckma :: kmən, 0.003181789046285499)
# ..                                       ...
# 115    (ess# :: inəs, 0.0015798911387924959)
# 116   (ton' :: tənz#, 0.0015761019501366147)
# 117   (#amt :: mtɹæk, 0.0015729762840564427)
# 118   (#star :: stɑɹ, 0.0015645000229375144)
# 119  (erman :: ɝmən#, 0.0015643969110070923)
#
#                                          89
# 0      (wick :: wɪk#, 0.004443914195441757)
# 1      (ello :: ɛɫoʊ, 0.003821268929772094)
# 2    (tson :: tsən#, 0.0037034354305959154)
# 3       (man# :: tmən, 0.00345563399676543)
# 4    (owski :: ski#, 0.0033254618289851228)
# ..                                      ...
# 115   (erton :: tən#, 0.001536391730335745)
# 116   (iff# :: ɫɪf#, 0.0015319659151561574)
# 117  (ling# :: əɫɪŋ, 0.0015313367140379322)
# 118   (tner :: tnɝ#, 0.0015255452526967829)
# 119   (#gar :: #ɡɑɹ, 0.0015247580864286626)
#
# [120 rows x 90 columns]

# %% [markdown]
# # 境界記号の処理

# %%
## supplement boudaries: this modification improves alignment quality
## But this modification most likely to do harm to paired terms
use_paired_terms = True
supplement_boundaries = True
boundary_mark = "#"
if supplement_boundaries and not use_paired_terms:
    for col in raw_df:
        enc = [ (f"{gap_mark}{term}", score) if term[-1] == boundary_mark else (f"{gap_mark}{term}{gap_mark}", score) for term, score in raw_df[col] ]
        raw_df[col] = enc
##
raw_df
# Out:
#                                          0   \
# 0      (#gal :: #ɡəɫ, 0.004248156812815527)
# 1    (erman :: tɝmə, 0.0032761726425191108)
# 2    (owski :: ski#, 0.0032534475311765615)
# 3     (#non :: #nɑnf, 0.003218828760648162)
# 4     (utche :: tʃɝ#, 0.003214399682457863)
# ..                                      ...
# 115   (mela :: #mɛɫ, 0.0015885525108991346)
# 116   (life :: #ɫaɪ, 0.0015813560486005285)
# 117  (ski# :: nski#, 0.0015777935119456025)
# 118   (ler# :: eɪɫɝ, 0.0015746788961115816)
# 119    (lect :: ɫɛkt, 0.001563560335746395)
#
#                                           1   \
# 0      (gton# :: ɪŋtə, 0.004291690380586001)
# 1     (#ligh :: #ɫaɪt, 0.003862912175634734)
# 2      (owsk :: ski#, 0.0035130428791565874)
# 3        (ted# :: stɪd, 0.00348225088567199)
# 4       (#ent :: #ɛnɝ, 0.003356694588500677)
# ..                                       ...
# 115    (ders :: ændɝ, 0.0015494075000850567)
# 116    (elin :: ɫɪn#, 0.0015459198528562515)
# 117  (#barb :: #bɑɹb, 0.0015419606173942204)
# 118  (lers# :: əɫɝz#, 0.0015363990264261396)
# 119  (amtra :: æmtɹæ, 0.0015312545994087422)
#
#                                          2   \
# 0     (land :: #ɫænd, 0.004342214301990682)
# 1    (enin :: ənɪŋ#, 0.0034972856783785596)
# 2    (erman :: ɝmən#, 0.003424881241823422)
# 3     (ned# :: ənd#, 0.0032949913338566695)
# 4      (ngs# :: ɫɪŋz, 0.003275517980179494)
# ..                                      ...
# 115   (#tom :: #toʊm, 0.001582410010961876)
# 116   (#ran :: #ɹæns, 0.001581059077192023)
# 117  (terma :: ɝmən, 0.0015808665287902447)
# 118   (ley# :: tɫi#, 0.0015806566824827116)
# 119  (ites :: aɪts#, 0.0015805802440594752)
#
#                                          3   \
# 0      (carb :: #kɑɹ, 0.004061346962031881)
# 1     (stry# :: tɹi#, 0.004052233440539947)
# 2      (#gra :: #ɡɹæ, 0.003982225838663347)
# 3     (ling# :: əɫɪŋ, 0.003622674870936606)
# 4     (ping# :: pɪŋ#, 0.003573835190723687)
# ..                                      ...
# 115    (#tra :: #tɹe, 0.001554274235956147)
# 116  (line :: ɫaɪn#, 0.0015525203441251495)
# 117   (nter :: #ɛnɝ, 0.0015417766845582973)
# 118  (rman# :: mən#, 0.0015396998992542631)
# 119   (evit :: ɛvɪt, 0.0015332719518631644)
#
#                                          4   \
# 0       (tock :: stɑk, 0.00441558156620048)
# 1        (kman :: kmən, 0.0040961140819052)
# 2     (oman :: oʊmə, 0.0035972365595806502)
# 3    (derma :: ɝmən, 0.0034899171942140146)
# 4     (ide# :: aɪd#, 0.0034172266039369163)
# ..                                      ...
# 115  (ting :: ɪtɪŋ#, 0.0015239252527665128)
# 116  (erton :: ɝtən, 0.0015225340011310801)
# 117   (ess# :: tɫəs, 0.0015177972731723552)
# 118  (dness :: dnəs, 0.0015051488447477186)
# 119   (term :: tɝmə, 0.0015015645459486079)
#
#                                          5   \
# 0      (ble# :: bəɫ#, 0.005563951476536451)
# 1      (ingt :: ɪŋtə, 0.003620751695214526)
# 2    (erlin :: ɝɫɪn, 0.0031587023466216006)
# 3     (#lig :: #ɫaɪ, 0.0030363359529131553)
# 4      (#lif :: ɫaɪf, 0.002940242966582451)
# ..                                      ...
# 115  (#mark :: #mɑɹ, 0.0014991696824870628)
# 116  (hart# :: hɑɹt#, 0.001497246871261972)
# 117   (mccu :: #mək, 0.0014942399020303366)
# 118   (ood# :: wʊd#, 0.0014926566450153107)
# 119   (#chit :: tʃɪt, 0.001481319106801145)
#
#                                           6   \
# 0       (#van :: #væn, 0.003759224453624997)
# 1     (#over :: oʊvɝ, 0.0037423630819394087)
# 2        (#mel :: #mɛɫ, 0.00372423802351194)
# 3      (righ :: ɹaɪt#, 0.003275270860145393)
# 4    (#ligh :: #ɫaɪt, 0.0030794745176119993)
# ..                                       ...
# 115    (nzo# :: zoʊ#, 0.0015142138381897534)
# 116   (nick# :: nɪk#, 0.0015088853424979516)
# 117    (boar :: bɔɹd, 0.0015031096146692494)
# 118     (#rad :: #ɹæd, 0.001502131453357985)
# 119   (derm :: dɝmən, 0.0015001122851729485)
#
#                                          7   \
# 0     (line# :: aɪn#, 0.005076014379245686)
# 1     (amtra :: mtɹæ, 0.005051521402055748)
# 2     (nsky :: nski, 0.0039700117434851336)
# 3      (derm :: mən#, 0.003594761103043637)
# 4      (ande :: #vænd, 0.00358300723372953)
# ..                                      ...
# 115   (ser# :: ɪsɝ#, 0.0015812481215197137)
# 116    (etti :: ɛti#, 0.001578877626064493)
# 117  (right :: ɹaɪt, 0.0015668567467522739)
# 118   (ing# :: #aʊt, 0.0015657369445078986)
# 119  (ters# :: stɝz#, 0.001563577832655399)
#
#                                          8   \
# 0       (eck# :: bɛk#, 0.00373008329555262)
# 1     (#far :: #fɑɹ, 0.0036475522155502123)
# 2    (rrow# :: ɹoʊ#, 0.0032662952524186405)
# 3    (flan :: #fɫæn, 0.0032178975555614405)
# 4      (flan :: #fɫæ, 0.003159939586298707)
# ..                                      ...
# 115  (chey# :: tʃi#, 0.0015672882928895382)
# 116   (shin :: ʃɪŋ#, 0.0015475289813329078)
# 117   (ler# :: sɫɝ#, 0.0015443420828485236)
# 118    (nski :: ski#, 0.001539849778796551)
# 119   (stam :: stæm, 0.0015395991889066067)
#
#                                          9   ...  \
# 0      (odge :: ɫɑdʒ, 0.004731948599928874)  ...
# 1     (#mai :: #meɪ, 0.0044755413224138434)  ...
# 2     (ence# :: əns#, 0.003912906271680249)  ...
# 3     (#galo :: #ɡəɫ, 0.003307218641964862)  ...
# 4    (#home :: #hoʊ, 0.0032044035703892183)  ...
# ..                                      ...  ...
# 115  (ridge :: ɪdʒ#, 0.0015140596124008018)  ...
# 116   (ding :: dɪŋ#, 0.0015078765259744463)  ...
# 117   (iff# :: ɫɪf#, 0.0015035140950261595)  ...
# 118   (#car :: #kɑɹb, 0.001503373019721552)  ...
# 119  (tes# :: aɪts#, 0.0014944620326020868)  ...
#
#                                          80  \
# 0    (ling# :: ɫɪŋ#, 0.0036955379675354233)
# 1     (ranc :: æns#, 0.0035013575593613486)
# 2      (#fre :: #fɹɛ, 0.003068433830260731)
# 3     (#mcn :: məkn, 0.0030357677589957755)
# 4     (ley# :: sɫi#, 0.0030033358217822588)
# ..                                      ...
# 115  (#bric :: #bɹɪ, 0.0015665149386007644)
# 116  (nds# :: ɫəndz, 0.0015619316142505078)
# 117   (#bri :: #bɹa, 0.0015611512272136166)
# 118  (#home :: hoʊm, 0.0015484658530254324)
# 119  (ers# :: əɫɝz#, 0.0015471271575577328)
#
#                                          81  \
# 0     (ille# :: vɪɫ#, 0.004282078839442345)
# 1      (tal# :: təɫ#, 0.004030772258205348)
# 2     (#gin :: #ɡɪn, 0.0036286063484179776)
# 3     (#amt :: tɹæk, 0.0034246137229986596)
# 4     (#whi :: #hwɪ, 0.0030609085424518965)
# ..                                      ...
# 115   (erto :: tən#, 0.0015140051393613225)
# 116   (ina# :: inə#, 0.0015032929229885491)
# 117   (rst# :: ɝst#, 0.0014924553364928164)
# 118  (elin :: ɪɫɪn#, 0.0014911827678547472)
# 119  (#gol :: #ɡoʊɫ, 0.0014897936588136288)
#
#                                          82  \
# 0      (erin :: ɝɪŋ#, 0.005185234375393777)
# 1    (atter :: ætɝ#, 0.0037860304054055318)
# 2     (#sto :: stɔɹ, 0.0037161256396394025)
# 3    (#beac :: #bit, 0.0036816270992873403)
# 4      (ick# :: wɪk#, 0.003517768511614072)
# ..                                      ...
# 115  (rship :: ʃɪp#, 0.0015265964206202212)
# 116   (beac :: bitʃ, 0.0015242666139431923)
# 117     (kel# :: ɪkəɫ, 0.00151987362451577)
# 118  (rton :: ɹtənz, 0.0015179277385475938)
# 119  (insk :: nski#, 0.0015054727951234073)
#
#                                           83  \
# 0         (oman :: oʊmə, 0.0059112803042083)
# 1       (vand :: vænd, 0.004355830836093759)
# 2     (annon :: ænən, 0.0033279224225545422)
# 3      (are# :: wɛɹ#, 0.0030018324767827373)
# 4     (#vand :: #væn, 0.0030001421144081938)
# ..                                       ...
# 115    (ansk :: ski#, 0.0015470621634459205)
# 116    (ansk :: ænsk, 0.0015434892342061938)
# 117    (#rot :: #ɹoʊ, 0.0015421473952079738)
# 118    (rton :: ɹtən, 0.0015334645249710473)
# 119  (#cass :: #kæsə, 0.0015259241117234902)
#
#                                          84  \
# 0    (#mess :: #mɛs, 0.0040403060957354625)
# 1      (utch :: kətʃ, 0.003825879705124558)
# 2    (illin :: ɪɫɪŋ, 0.0032463516785429217)
# 3     (ster :: stɝz#, 0.003176975489670759)
# 4     (rant :: ɝænt, 0.0031700257963251906)
# ..                                      ...
# 115  (ston# :: tən#, 0.0014963066222181021)
# 116   (ters :: stɝz, 0.0014948100650553806)
# 117   (rst# :: ɝst#, 0.0014941625701995623)
# 118  (ashi# :: ɑʃi#, 0.0014938017100956733)
# 119  (ashin :: ʃɪŋ#, 0.0014896395994332113)
#
#                                           85  \
# 0       (nks# :: ŋks#, 0.005103190217820056)
# 1      (ding :: ɪdɪŋ#, 0.003972810242264332)
# 2      (#rep :: #ɹip, 0.0038265393476635944)
# 3       (rd's :: ɑɹdz#, 0.00360101305294283)
# 4     (on's# :: tənz, 0.0031821267440594056)
# ..                                       ...
# 115    (#fen :: #fɛn, 0.0015372368944554305)
# 116  (erson :: ɝsən#, 0.0015358960251562548)
# 117    (#gan :: #ɡæn, 0.0015335954719108192)
# 118    (nski :: ɪnsk, 0.0015311952743720424)
# 119    (#bac :: #bæk, 0.0015289764162576213)
#
#                                           86  \
# 0      (life :: #ɫaɪf, 0.005256599738198006)
# 1       (less :: tɫəs, 0.004591930732290849)
# 2       (art# :: ɪnhɑ, 0.004392788676127281)
# 3      (#par :: #pɛɹə, 0.004116585827694997)
# 4        (ide# :: aɪd#, 0.00378133316494361)
# ..                                       ...
# 115    (#gol :: ɡoʊɫ, 0.0014973853672511307)
# 116  (ites# :: aɪts#, 0.0014970889068128357)
# 117    (ged# :: dʒd#, 0.0014779320298910713)
# 118    (#for :: #fɔɹ, 0.0014768050759806704)
# 119    (mark :: #mɑɹ, 0.0014766653412385045)
#
#                                          87  \
# 0     (ider :: aɪdɝ#, 0.004816085920841073)
# 1     (idge# :: ɪdʒ#, 0.004275297650450445)
# 2      (ord# :: fɝd#, 0.004108505379615207)
# 3      (ship# :: ʃɪp#, 0.00386899489171738)
# 4      (#lan :: ɫænd, 0.003827321658400536)
# ..                                      ...
# 115   (#sna :: #snæ, 0.0015754812186473848)
# 116  (inski :: ɪnsk, 0.0015696451020858952)
# 117   (#sun :: #sən, 0.0015671462854806079)
# 118   (del# :: dəɫ#, 0.0015603017160660375)
# 119   (ansk :: ski#, 0.0015546466188142711)
#
#                                           88  \
# 0      (lings :: ɪŋz#, 0.004245911162598869)
# 1        (ight :: ɫaɪt, 0.00363721160378063)
# 2      (#van :: vænd, 0.0036320409576697664)
# 3       (der# :: ndɝ#, 0.003221218003074198)
# 4       (ckma :: kmən, 0.003181789046285499)
# ..                                       ...
# 115    (ess# :: inəs, 0.0015798911387924959)
# 116   (ton' :: tənz#, 0.0015761019501366147)
# 117   (#amt :: mtɹæk, 0.0015729762840564427)
# 118   (#star :: stɑɹ, 0.0015645000229375144)
# 119  (erman :: ɝmən#, 0.0015643969110070923)
#
#                                          89
# 0      (wick :: wɪk#, 0.004443914195441757)
# 1      (ello :: ɛɫoʊ, 0.003821268929772094)
# 2    (tson :: tsən#, 0.0037034354305959154)
# 3       (man# :: tmən, 0.00345563399676543)
# 4    (owski :: ski#, 0.0033254618289851228)
# ..                                      ...
# 115   (erton :: tən#, 0.001536391730335745)
# 116   (iff# :: ɫɪf#, 0.0015319659151561574)
# 117  (ling# :: əɫɪŋ, 0.0015313367140379322)
# 118   (tner :: tnɝ#, 0.0015255452526967829)
# 119   (#gar :: #ɡɑɹ, 0.0015247580864286626)
#
# [120 rows x 90 columns]

# %% [markdown]
# # 解析

# %%
## integrate redundant terms by superposition
import term_handler

##
topics_df = raw_df

## run the following if you need to make effective your updates in the module
reload_module = False
if reload_module:
    import importlib
    importlib.reload(term_handler)

## Good paramterization is crucial for convergence. Here are two samples of good one for
## global and another for local alignments. NB: different values would generate unexitable loop.
## Acceptable setting for global alignment
global_align_params = {
            'gap_weight'      : -2, # This may not be smaller
            'match_weight'    :  3,
            'mismatch_weight' : -2,
            'theta'           :  0 # If it takes too long to complete, try out a larger value.
            }
## Acceptable setting for local alignment: Local alignment is more robust for variation
local_align_params = {
            'gap_weight'      : -2.5,
            'match_weight'    :  1,
            'mismatch_weight' : -2.5,
            'theta'           :  0 # If it takes too long to complete, try out a larger value.
            }

## settings for execution
align_globally = False
if align_globally:
    method = "globally"
else:
    method = "locally"
expansive      = True
greedy         = True # This attribute is largely incompatible with global alignment
detailed       = True
check          = False

## main
print(f"method: {method}")
print(f"greedy: {greedy}")
print(f"expansive: {expansive}")
print(f"detailed: {detailed}")
print(f"check: {check}")    
for tid in topics_df:
    topic_data = topics_df[tid]
    if check:
        print(topic_data)
    #
    terms_as_dict = { }
    for data in topic_data:
        term, score = data[0], data[1]
        try:
            val = float(score)
            terms_as_dict[str(term)] = val
        except ValueError:
            print(f"#{score}")
    if check:
        print(terms_as_dict)
    ## resurively update data
    T = list(terms_as_dict.keys())
    if align_globally:
        O = term_handler.derive_terms_by_superposition(T, align_globally = True, expansive = expansive, greedy = greedy, check = check, **global_align_params)
    else:
        O = term_handler.derive_terms_by_superposition(T, align_globally = False, expansive = expansive, greedy = greedy, check = check, **local_align_params)
    ## show result
    if detailed:
        T = sorted(T, key = lambda x: (len(x) - x.count(gap_mark) - x.count("[") - x.count("]")), reverse = True)
        print(f"topic {tid:03} has {len(T):03} raw terms: {T}")
    #
    O = [ x for x in O if not x in T ] # Filter out terms already in originals 
    O = sorted(O, key = lambda x: (len(x) - x.count(gap_mark) - x.count("[") - x.count("]")), reverse = True)
    print(f"topic {tid:03} found {len(O):03} {method} superposed terms: {O}")
##
print(f"# Topic-wise term integration for HDP/LDA {max_n_topics} topics via {target_lang_dict[target_lang_key]} {target_class}{term_type}{accent_status}")
# Out:
# method: locally
# greedy: True
# expansive: True
# detailed: True
# check: False
# topic 000 has 120 raw terms: ['nski# :: nski#', '#life :: #ɫaɪf', 'tman# :: tmən#', 'lland :: ɫənd#', 'nnon# :: ænən#', 'sters :: stɝz#', 'amtra :: #æmtɹ', "ton's :: ɹtənz", 'amtra :: æmtɹæ', 'erman :: tɝmə', 'owski :: ski#', '#non :: #nɑnf', 'utche :: tʃɝ#', 'nnick :: nɪk#', '#cas :: #kæsə', 'idge :: ɹɪdʒ#', 'den# :: ɫdən#', 'erso :: ɝsən#', 'ling :: əɫɪŋ#', 'nski# :: ɪnsk', 'llan :: ɫənd#', '#bol :: #boʊɫ', 'led# :: təɫd#', '#land :: #ɫæn', 'ers# :: ndɝz#', 'terma :: ɝmən', '#scar :: skɛɹ', '#chi :: #tʃɪt', 'elin# :: ɫɪn#', 'maste :: mæst', 'ancy# :: nsi#', 'hart :: nhɑɹt', 'line# :: ɫaɪn', 'wood# :: wʊd#', 'ship# :: ɝʃɪp', 'erma :: ɝmən#', 'ppert :: pɝt#', 'aro# :: ɑɹoʊ#', 'ters# :: stɝz', 'light :: ɫaɪt', 'gton# :: ŋtən', 'tman# :: tmən', 'ider :: aɪdɝ#', 'mela :: #mɛɫə', 'dge# :: ɹɪdʒ#', 'berg# :: bɝɡ#', '#swin :: #swɪ', 'rship :: ɝʃɪp', 'amtr :: #æmtɹ', 'nski :: ɪnski', '#rock :: #ɹɑk', 'insk :: ɪnski', '#sund :: sənd', 'annon :: nən#', 'liff# :: ɫɪf#', '#sand :: sænd', 'ling# :: ɫɪŋ#', 'annon :: ænən', 'ski# :: nski#', '#gal :: #ɡəɫ', 'ans# :: ənz#', 'nder :: ɛndɝ', 'sky# :: ski#', 'ome# :: kəm#', 'oad# :: oʊd#', '#wei :: #waɪ', 'nia# :: niə#', '#nak :: #nɑk', 'ncy# :: ænsi', 'tman :: mən#', 'ings :: ɪŋz#', 'land :: ɫænd', 'ckma :: kmən', 'guir :: #məɡ', 'wild :: waɪɫ', '#bar :: bɑɹb', 'ing# :: ɛɹɪŋ', 'ing# :: vɪŋ#', '#mcn :: məkn', 'herr :: #ʃɛɹ', 'wski :: ski#', 'eld# :: fɛɫd', '#hun :: #hən', 'ted# :: təd#', "t's# :: ɪts#", '#wel :: #wɛɫ', 'ola# :: ʊɫə#', 'tson :: tsən', '#sta :: stɑɹ', '#boh :: #boʊ', '#pro :: pɹoʊ', 'out# :: aʊt#', 'ded# :: dɪd#', "d's# :: ɑɹdz", '#jer :: dʒɛɹ', 'son# :: ɫɪsə', 'man# :: ɝmən', 'ers# :: ndɝz', 'ord# :: fɝd#', 'lers :: əɫɝz', 'use# :: juz#', 'toma :: toʊm', 'come :: kəm#', '#bea :: bitʃ', 'less :: ɫəs#', '#dal :: deɪɫ', 'ines :: inəs', 'anno :: nən#', 'town :: taʊn', 'carb :: #kɑɹ', 'agge :: æɡd#', 'rson :: ɝsən', 'ngle :: ŋɡəɫ', 'ion# :: ʃən#', 'eld# :: ɛɫd#', 'ity# :: əti#', 'mela :: #mɛɫ', 'life :: #ɫaɪ', 'ler# :: eɪɫɝ', 'lect :: ɫɛkt']
# topic 000 found 181 locally superposed terms: ['ling#::əɫɪŋ#', '#bo[h,l]::#boʊ', 'ing#::[v,ɫ]ɪŋ#', 'tman#::tmən#', 'man#::[t,ɝ]mən', 'lland::ɫənd#', 'nnon#::ænən#', 'nski#::ɪnski', 'amtra::#æmtɹ', 'ski#::nski#', 'nski#::ɪnsk', 'erman::tɝmə', 'and::[s,ɫ]ænd', 'ship#::ɝʃɪp', 'tman#::tmən', 'nnon#::ænən', 'ters#::stɝz', 'nski::ɪnski', 'ski#::ɪnski', 'annon::nən#', 'annon::ænən', 'dge#::ɹɪdʒ#', 'son::[t,ɝ]sən', 'wski::ski#', 'ome#::kəm#', 'd#::[o,w]ʊd#', 'ski#::ɪnsk', 'ncy#::ænsi', 'ers#::ndɝz', 'ma::[k,ɝ]mən', 'erma::ɝmən', 'land::#ɫæn', 'eld#::fɛɫd', 'nd::[s,ɫ]ənd', 'mela::#mɛɫ', 'lin[e,g]#::ɫ', 'life::#ɫaɪ', 'man#::tɝmə', 'rson::ɝsən', '#we[i,l]::#w', 'man#::ɝmən', '::ɝ[m,s]ən#', '::[t,ɝ]mən#', 'ling#::ɫɪ', 'n::[m,n]ən#', '::[#,ŋ]ɡəɫ', '#::nski#', 'lin[#,g]::', 'ers[#,o]::', '::[t,ɝ]mən', '::[k,t]mən', '::[k,ɝ]mən', 'ing[#,s]::', '::[p,ɑ]ɹoʊ', '::[ŋ,ɹ]tən', 'ler[#,s]::', 'ine[#,s]::', '::[m,n]ən#', '::[n,ʃ]ən#', '::[s,ɫ]ənd', '::[t,ɝ]sən', 'line#::ɫ', '::[m,ʃ]ən#', 'ed#::tə', 'land::ɫ', '::ɝmən#', 'man#::t', '::ænən#', '::ɪnski', '::ski#', 'ski#::', 'ings::', 'ing#::', '::ɪnsk', '::ɛndɝ', 'ers#::', '::ɝmən', '::kmən', '::#waɪ', '::#ɫaɪ', 'land::', 'non#::', 'erso::', '::ɝsən', '::tsən', '::deɪɫ', 'carb::', 'n#::ɫɪ', 'son#::', 'ski::', 'ed#::', '#::æn', 'd#::f', "'s#::", '#::ɑɹ', '::ɫaɪ', 'and::', 'on#::', 'ers::', 'nd::s', '#::ɫɪ', 'non::', 'man::', '#::ns', 'n#::ɫ', '::#nɑ', 'n::mə', 'der::', 'l::#', 'al::', '::sk', 'ck::', '::#k', 'y#::', '#::s', 'e#::', 'd#::', '::əɫ', '#::ɪ', '#::t', '::æn', 's#::', '#::n', 'ma::', 'i::#', 'nd::', 'g#::', '#::ɛ', 'r::#', 'n::#', 'a#::', '#::ɝ', 't::ɫ', 'n#::', '::ɫə', '::st', 'er::', '::#m', 'a::#', 'n::t', '#::ɫ', 'on::', '::#ɫ', 'an::', '#::ə', 'ge::', 'ar::', 'rt::', 'k::#', '::#', 'i::', '::s', '::t', 'e::', '::n', 'k::', 's::', '#::', '::k', '::ə', '::ɪ', 'l::', '::æ', '::ɝ', 'a::', '::m', '::ɫ', 'd::', '::w', '::ɛ', 'r::', 'n::', 't::', '::d', '::ŋ', '::b', 'o::', '::ɹ', '::p', '::a', '::']
# topic 001 has 120 raw terms: ['#ligh :: #ɫaɪt', 'nders :: ndɝz#', 'ters# :: stɝz#', 'dness :: dnəs#', '#down :: #daʊn', 'inski :: nski#', 'amtra :: #æmtɹ', 'vande :: #vænd', 'erson :: ɝsən#', '#barb :: #bɑɹb', 'lers# :: əɫɝz#', 'amtra :: æmtɹæ', 'gton# :: ɪŋtə', 'ever# :: ivɝ#', '#life :: ɫaɪf', '#chit :: tʃɪt', 'ing# :: ɛɹɪŋ#', '#wil :: #waɪɫ', 'tson# :: sən#', '#vand :: vænd', '#mar :: #mɑɹk', 'ting# :: tɪŋ#', 'led# :: təɫd#', '#mcd :: #məkd', 'inski :: ɪnsk', 'rance :: æns#', "rton' :: ənz#", 'tran :: #tɹæn', 'mtra :: æmtɹæ', 'nder# :: ndɝ#', 'lman# :: mən#', '#mast :: #mæs', 'atley :: tɫi#', 'ight# :: aɪt#', 'erman :: dɝmə', '#fran :: #fɹæ', 'barb :: #bɑɹb', '#lig :: #ɫaɪt', 'mcgui :: #məɡ', 'ton# :: ɪŋtən', 'man# :: ɫmən#', 'non# :: ænən#', '#mess :: #mɛs', 'lling :: ɪɫɪŋ', 'inger :: ɪŋɝ#', 'amtr :: #æmtɹ', 'fers# :: fɝz#', 'atter :: ætɝ#', '#bea :: #bitʃ', 'maste :: æstɝ', 'man# :: tmən#', 'each :: #bitʃ', 'ancy# :: nsi#', 'able# :: bəɫ#', 'feld :: fɛɫd#', 'dness :: nəs#', 'nzo# :: nzoʊ#', 'rance :: ɹæns', 'tman :: tmən#', '#hand :: #hæn', 'derma :: ɝmən', '#chit :: #tʃɪ', 'oggle :: ɑɡəɫ', 'owsk :: ski#', 'ted# :: stɪd', '#ent :: #ɛnɝ', 'life :: #ɫaɪ', 'tman :: mən#', 'ashi :: ɑʃi#', 'acti :: æktɪ', 'ens# :: ənz#', 'ide# :: aɪd#', 'ter# :: ɪstɝ', 'ger# :: ɪŋɝ#', 'inge :: ɪŋɝ#', 'est# :: əst#', "d's# :: ɪdz#", 'nsky :: ski#', 'born :: bɔɹn', 'bric :: #bɹɪ', '#sti :: #stɪ', '#cul :: #kəɫ', 'ert# :: pɝt#', '#har :: hɑɹd', "d's# :: ɹdz#", '#hed :: #hɛd', 'lin# :: ɪɫɪn', 'mela :: mɛɫə', 'down :: #daʊ', 'son# :: tsən', 'ster :: ɪstɝ', 'stoc :: stɑk', 'tti# :: ɛti#', 'yer# :: aɪɝ#', 'rman :: ɹmən', 'ged# :: dʒd#', 'ner# :: ɡnɝ#', 'ashi :: ʃɪŋ#', 'anno :: ænən', 'ton# :: stən', '#gro :: ɡɹoʊ', 'ore# :: mɔɹ#', 'ers# :: stɝz', 'sen# :: sən#', "ton' :: ənz#", '#del :: #dɛɫ', '#mat :: #mæθ', '#cam :: #kæm', 'mccu :: #mək', 'rton :: ɝtən', '#gro :: #ɡɹo', "rd's :: ɹdz#", 'bric :: bɹɪk', 'wate :: wɔtɝ', 'nnon :: ænən', 'sher :: #ʃɛɹ', 'ence :: əns#', 'rman :: mən#', 'ders :: ændɝ', 'elin :: ɫɪn#']
# topic 001 found 186 locally superposed terms: ['man#::[t,ɫ]mən#', 'nsk[i,y]::nski#', 'vande::#vænd', "d's#::[ɪ,ɹ]dz#", 'nder[#,s]::ndɝ', 'der[#,s]::ændɝ', 'man#::[ɫ,ɹ]mən', 'man#::[t,ɹ]mən', 'rman::[ɝ,ɹ]mən', 'dness::dnəs#', 'ton#::[s,ɝ]tən', 'son#::[t,ɝ]sən', '#ligh::#ɫaɪt', 'ster::[æ,ɪ]stɝ', 'amtra::#æmtɹ', '#chit::#tʃɪ', 'man#::ɫmən#', 'man#::tmən#', 'tman::tmən#', 'son#::ɝsən#', 'ters#::ɪstɝ', 'inski::ɪnsk', 'inger::ɪŋɝ#', 'erman::dɝmə', 'barb::#bɑɹb', 'man::[t,ɹ]mən', 'rance::ɹæns', 'nce::[æ,ə]ns#', 'mtra::#æmtɹ', 'lin[#,g]::ɪɫɪ', 'mtra::æmtɹæ', 'ton#::ɪŋtə', 'life::#ɫaɪ', 'man#::mən#', 'n#::[m,s]ən#', 'son#::tsən', 'ter#::ɪstɝ', 'man#::ɹmən', "d's#::ɹdz#", 'non#::ænən', 'down::#daʊ', 'ger#::ɪŋɝ#', 'ers#::stɝz', 'rman::ɹmən', 'nnon::ænən', '#gro::#ɡɹo', "ton'::ənz#", 'man::tmən#', 'rman::ɝmən', 'bric::#bɹɪ', 'lin#::ɪɫɪn', 'ders::ændɝ', '#mast::#mæ', '#ma[r,t]::#m', 'man::ɹmən', 'man::mən#', "ton[#,']::", '::[m,s]ən#', 'n#::sən#', '::[æ,ɪ]stɝ', 'nsk[i,y]::', 'ing[#,e]::', '::[ɝ,ɫ]mən', '::[t,ɝ]mən', 'n#::tsən', '::[t,ʃ]ɪŋ#', '::nski#', '#::ɪstɝ', 'inge::ɪ', 'tran::#', 'ande::#', "rton'::", '::ɝsən#', '::#bitʃ', 'maste::', 'ton#::', '::ski#', '::#ɫaɪ', '::ɝmən', 'on#::s', '::vænd', 'er#::ɪ', 'ter#::', '::ɪŋɝ#', 'tran::', 'ran::#', 'man#::', 'rman::', '::ænən', 'ers#::', '::ɪstɝ', '::æstɝ', '::ənz#', "ton'::", 'ling::', 'ing#::', 'ashi::', '::#mək', '::#stɪ', 'on#::', '#::ɪŋ', 'n#::ɪ', 'man::', 'and::', '#::aɪ', 'ed#::', 'er#::', 'ess::', 'er::ɪ', '#::st', 'ter::', 'n#::t', 'nce::', 'd::#h', 'on::ɝ', 's#::ə', '::#mə', 'n#::s', '#::ɪ', '::ɪŋ', 'n#::', 't::#', 'an::', '#::s', 'ti::', 'e#::', '#::t', 's#::', 'n::#', '::#t', '#::n', '#::m', '::#b', 'l::#', '::#k', 't#::', 'ar::', '::æn', '::#m', '::#d', 'er::', '::st', '::ns', 's::n', '::ən', 'd::#', 'on::', 'r::#', '#::ə', 'h::#', '#::ɛ', 'e::æ', 'a::#', 'e::#', 'i::#', 'te::', '#::', '::ɪ', '::s', '::#', 't::', 'e::', '::ɫ', '::t', 'n::', '::m', 'd::', 'i::', '::æ', '::n', 'y::', '::d', '::b', 'r::', '::ɹ', 's::', '::f', 'c::', 'o::', '::ɡ', '::ə', 'a::', '::ɝ', '::ɑ', 'g::', '::']
# topic 002 has 120 raw terms: ['erman :: ɝmən#', 'nsky# :: nski#', 'ster# :: mstɝ#', 'annon :: ænən#', 'erson :: ɝsən#', 'eson# :: ɪsən#', 'land :: #ɫænd', 'enin :: ənɪŋ#', 'ngto :: ŋtən#', 'ers# :: əɫɝz#', 'ster :: mæstɝ', 'man# :: ɝmən#', '#mcgu :: məɡɝ', '#sto :: #stɔɹ', '#shat :: #ʃæt', 'aker :: eɪkɝ#', 'gton# :: ŋtən', '#pro :: #pɹoʊ', 'lodge :: ɫɑdʒ', 'ers# :: ndɝz#', 'ster# :: stɝ#', 'ming# :: mɪŋ#', 'ston# :: tən#', "d's# :: ɑɹdz#", 'ton# :: stən#', '#cas :: #kæsə', 'outr :: #aʊtɹ', '#hard :: hɑɹd', 'mmel# :: məɫ#', 'lass :: #kɫæs', 'ncy# :: ænsi#', '#vand :: vænd', '#inte :: #ɪnt', 'son# :: ɫsən#', '#mel :: #mɛɫə', 'nnon# :: nən#', '#out :: #aʊtɹ', 'ship# :: ʃɪp#', '#han :: #hænd', 'agged :: æɡd#', 'ider# :: aɪdɝ', '#bar :: #bɑɹb', 'rman :: ɝmən#', "on's# :: ɹtən", 'mela :: #mɛɫə', 'tson :: tsən#', '#tom :: #toʊm', '#ran :: #ɹæns', 'terma :: ɝmən', 'ites :: aɪts#', 'ned# :: ənd#', 'ngs# :: ɫɪŋz', 'kin# :: kɪn#', 'arti :: #ɑɹt', 'man# :: tmən', 'guir :: #məɡ', 'derm :: ɝmən', 'ring :: ɹɪŋ#', '#gar :: #ɡɑɹ', 'rton :: ɹtən', '#pro :: #pɹo', 'ted# :: ɪtəd', 'sky# :: nski', 'aste :: mæst', '#wes :: #wɛs', '#dis :: #dɪs', 'ton# :: tən#', 'ders :: ændɝ', 'ranc :: æns#', '#lif :: #ɫaɪ', '#ent :: #ɛnɝ', 'gan# :: ɡən#', '#col :: koʊɫ', 'ings :: ɫɪŋz', '#tri :: #tɹɪ', 'ero# :: ɹoʊ#', 'eson :: ɪsən', 'iste :: ɪstɝ', 'ata# :: ɑtə#', 'ley# :: sɫi#', 'ked# :: ɑkt#', 'erso :: sən#', 'nzer :: nzɝ#', '#sta :: stɑɹ', 'own# :: aʊn#', 'mel# :: məɫ#', 'nder :: ændɝ', 'agge :: æɡd#', 'down :: #daʊ', '#sna :: #snæ', 'righ :: aɪt#', '#coa :: #koʊ', 'weis :: #waɪ', 'ges# :: dʒəz', 'lers :: ɫɝz#', 'mail :: meɪɫ', '#rit :: #ɹɪt', '#art :: #ɑɹt', 'beck :: bɛk#', 'mtra :: æmtɹ', '#mel :: mɛɫə', 'trac :: tɹæk', '#non :: nɑnf', 'nter :: ɪntɝ', 'son# :: ɫsən', 'amtr :: mtɹæ', 'erma :: ɝmən', 'ner# :: snɝ#', 'nnon :: ænən', '#dow :: #daʊ', 'lass :: #kɫæ', '#mel :: #mɛɫ', 'ner# :: ɡnɝ#', 'ngto :: tən#', 'herr :: #ʃɛɹ', 'naka :: #nɑk', 'ande :: #væn', 'hand :: #hæn', 'aker :: ɪkɝ#', 'ley# :: tɫi#']
# topic 002 found 212 locally superposed terms: ['son#::[ɝ,ɪ]sən#', 'son#::[ɪ,ɫ]sən#', 'son#::[t,ɪ]sən#', 'son#::[t,ɫ]sən#', 'son#::[ɝ,ɫ]sən#', 'man#::[t,ɝ]mən', 'ing#::[m,ɹ]ɪŋ#', 'ton#::[ŋ,ɹ]tən', 'ton#::[s,ɹ]tən', 'ton#::[s,ŋ]tən', 'ster#::mæstɝ', 'ster#::mstɝ#', '#co[a,l]::#koʊ', 'nnon#::ænən#', 'son#::[ɪ,ɫ]sən', 'ley#::[s,t]ɫi#', 'erson::ɝsən#', 'son#::[ɝ,ɫ]sən', 'son#::[t,ɫ]sən', 'ner#::[s,ɡ]nɝ#', 'son::[t,ɝ]sən#', 'man#::ɝmən#', 'erman::ɝmən', 'rman::ɝmən#', 'ers#::əɫɝz#', 'aker::eɪkɝ#', 'ton#::stən#', 'on#::[n,t]ən#', 'outr::#aʊtɹ', 'eson#::ɪsən', 'agged::æɡd#', 'nnon#::ænən', 'mela::#mɛɫə', 'son::[t,ɪ]sən', 'son::[ɝ,ɪ]sən', '#mel::#mɛɫə', 'ngto::ŋtən#', 'n::ɝ[m,s]ən#', 'ngs#::ɫɪŋz', 'arti::#ɑɹt', 'sky#::nski', 'ton#::ɹtən', 'ton#::ŋtən', 'ton#::tən#', 'n#::[t,ɡ]ən#', 'n#::[n,ɡ]ən#', 'nnon::ænən', 'mel#::məɫ#', 'lass::#kɫæ', 'ande::#væn', 'mtra::æmtɹ', 'son#::ɫsən', 'erma::ɝmən', 'rman::ɝmən', 'mela::#mɛɫ', 'ster::mæst', '#pro::#pɹo', 'ers#::ændɝ', 'ders::ændɝ', 'nter::#ɪnt', '#mel::#mɛɫ', 'hand::#hæn', 'down::#daʊ', '::#[h,ɫ]ænd', '#::[ŋ,ɹ]tən', 'o::[s,t]ən#', '::ɝ[m,s]ən#', '#::[s,ɹ]tən', '::[s,ŋ]tən#', 'ers[#,o]::', '::[t,ɝ]mən', '::[ŋ,ɹ]tən', '#st[a,o]::', '::[s,t]ən#', 'ing[#,s]::', '::[m,ɪ]stɝ', '::[s,ɡ]ən#', '::[t,ɡ]ən#', 'mel[#,a]::', '::[n,s]ən#', '::[n,t]ən#', 'der[#,m]::', 'der[#,s]::', 'der[m,s]::', 'ande::#', '::ŋtən#', '#::ɹtən', '::tsən#', 'mel#::m', '::ɪsən#', '::stən#', '::ɫsən#', 'non#::n', 'ster#::', 'and::#', '::ɝmən', 'ers#::', '::#məɡ', 'ings::', '::ɹtən', '::ŋtən', '::tən#', 'ranc::', 'ter#::', '::hɑɹd', 'mel#::', 'ster::', '::ɪstɝ', 'erso::', '::ɪsən', '::ɫsən', '::vænd', 'trac::', '::mtɹæ', 'der#::', 'nder::', 'derm::', '::ændɝ', 'er#::s', 'own#::', 'and::', 'n#::t', 'an#::', 'on#::', 'is::#', '::æns', 'er#::', "'s#::", 'non::', 's::#k', 'ste::', 'ers::', 'er::ɪ', 'an::#', 'ter::', 'ar::#', 'ed#::', '::aɪt', 's::#w', '#::st', '::#ɫ', 'an::', 's#::', '#::ɫ', 'i::#', '#::ə', 'n#::', '#::t', 'r::#', '::#m', '#::n', 'y#::', 'on::', 'to::', 'o::#', '::#s', 'er::', 's::#', '::#d', 'ge::', '::æn', '#::m', '#::ɑ', '#::ɡ', 'tr::', '::mə', '::#k', '::ɪs', 'te::', '#::ɪ', '#::s', '::st', 'a::#', 's::ɫ', 't::#', '::#ɹ', '#::a', '::aɪ', 'e::#', 'n::#', '::ən', 'r::m', '::#t', 'l::m', '#::ɹ', '::#ʃ', 'es::', '::#', 'd::', 'n::', '#::', '::ɫ', '::ə', '::t', 'r::', '::ɹ', '::n', 'o::', 's::', 'e::', '::æ', 'c::', '::m', '::k', 'l::', '::ɪ', '::s', 'a::', '::ɝ', 'm::', '::a', '::']
# topic 003 has 120 raw terms: ['feld# :: fɛɫd#', 'hart# :: hɑɹt#', "on's# :: ɹtənz", 'amtra :: #æmtɹ', 'maste :: mæstɝ', 'less# :: tɫəs#', '#wild :: waɪɫd', 'stry# :: tɹi#', 'ling# :: əɫɪŋ', 'ping# :: pɪŋ#', 'erto :: ɝtən#', '#wil :: waɪɫd', 'sky# :: nski#', 'ening :: nɪŋ#', 'ening :: ənɪŋ', 'amtr :: #æmtɹ', 'try# :: stɹi#', 'rton# :: ɝtən', 'light :: ɫaɪt', 'llman :: ɫmən', 'mcgu :: #məɡɝ', 'gged# :: æɡd#', '#sta :: #stæm', 'and# :: ɫənd#', 'art# :: ɪnhɑɹ', 'over :: #oʊvɝ', 'nger# :: ɪŋɝ#', 'beach :: bitʃ', '#swin :: #swɪ', '#wil :: #waɪɫ', 'hart# :: ɑɹt#', '#sand :: #sæn', 'sters :: stɝz', '#stor :: #stɔ', 'enter :: #ɛnɝ', "ter's :: tɝz#", "on's# :: tənz", 'lers# :: ɫɝz#', 'mster :: stɝ#', '#bea :: #bitʃ', '#mela :: mɛɫə', 'less# :: ɫəs#', 'ingt :: ŋtən#', '#mar :: #mɑɹk', 'mtra :: #æmtɹ', 'ley# :: eɪɫi#', 'man# :: ɹmən#', 'ght# :: ɹaɪt#', 'toma :: #toʊm', 'erso :: ɝsən#', 'ider :: aɪdɝ#', '#shat :: #ʃæt', 'ight :: #ɫaɪt', 'barb :: #bɑɹb', '#dal :: #deɪɫ', 'line :: ɫaɪn#', 'rman# :: mən#', 'carb :: #kɑɹ', '#gra :: #ɡɹæ', 'lect :: ɫɛkt', 'bran :: #bɹæ', 'ley# :: ɪɫi#', 'ware :: wɛɹ#', "n's# :: tənz", 'ing# :: zɪŋ#', "y's# :: eɪz#", 'ford :: fɝd#', 'nia# :: niə#', 'kman :: kmən', 'tch# :: ɪtʃ#', '#mar :: mɑɹk', 'ster :: mæst', 'hart :: nhɑɹ', 'ing# :: tɪŋ#', 'ding :: dɪŋ#', 'ona# :: ʊnə#', 'ggle :: ɡəɫ#', 'cart :: kɑɹt', 'erso :: ɝsən', '#bor :: #bɔɹ', 'line :: aɪn#', '#fra :: #fɹæ', 'lle# :: vɪɫ#', 'nnon :: nən#', '#art :: #ɑɹt', '#gla :: #ɡɫæ', 'amtr :: tɹæk', 'feld :: ɛɫd#', 'der# :: ndɝ#', 'oat# :: oʊt#', 'est# :: ɛst#', 'rans :: ɹæns', 'elin :: ɫɪn#', '#kal :: #kæɫ', 'able :: bəɫ#', 'ape# :: eɪp#', 'rton :: tən#', 'ler# :: eɪɫɝ', 'rton :: tənz', 'shin :: ʃɪŋ#', '#mcg :: #məɡ', '#col :: koʊɫ', 'etta :: ɛtə#', '#fan :: #fæn', 'sner :: snɝ#', 'oted :: tɪd#', 'ess# :: ɫəs#', 'aro# :: ɑɹoʊ', 'kel# :: ɪkəɫ', '#gan :: #ɡæn', 'and# :: ənd#', 'arro :: ɹoʊ#', 'and# :: ɫənd', 'ligh :: #ɫaɪ', 'son# :: ɪsən', '#bal :: #bæɫ', '#gol :: ɡoʊɫ', '#tra :: #tɹe', 'nter :: #ɛnɝ', 'evit :: ɛvɪt']
# topic 003 found 199 locally superposed terms: ['car[b,t]::#kɑɹ', 'ing#::[n,p]ɪŋ#', 'ing#::[p,z]ɪŋ#', 'ing#::[p,t]ɪŋ#', 'ing#::[d,p]ɪŋ#', '#wild::waɪɫd', 'ing#::[n,z]ɪŋ#', 'ing#::[n,t]ɪŋ#', 'amtra::#æmtɹ', 'feld#::fɛɫd#', 'art#::[h,k]ɑɹt', 'art#::[#,h]ɑɹt', 'hart#::hɑɹt#', 'ing#::[d,z]ɪŋ#', 'ing#::[d,t]ɪŋ#', 'line::[a,ɫ]ɪn#', '#wild::#waɪɫ', "on's#::ɹtənz", 'less#::tɫəs#', 'ght#::[ɫ,ɹ]aɪt', 'ing#::[t,z]ɪŋ#', 'man#::[k,ɹ]mən', 'man#::[ɫ,ɹ]mən', '#wil::#waɪɫ', 'ening::ənɪŋ', 'ing::[d,n]ɪŋ#', 'mtra::#æmtɹ', 'hart#::nhɑɹ', 'rton#::ɝtən', 'art#::ɪnhɑɹ', 'art::[#,k]ɑɹt', 'line::ɫaɪn#', "ter's::stɝz", 'rton::ɝtən#', 'ess#::tɫəs#', 'and#::ɫənd#', 'man#::ɹmən#', 'try#::stɹi#', 'ley#::eɪɫi#', '#mar::#mɑɹk', 'ight::#ɫaɪt', 'light::#ɫaɪ', 'man::[k,ɫ]mən', "n's#::ɹtənz", 'le::[b,ɡ]əɫ#', 'art#::kɑɹt', 'mcgu::#məɡ', 'erso::ɝsən', 'art#::#ɑɹt', 'ster::mæst', "n's#::tənz", 'on::[n,t]ən#', 'ess#::ɫəs#', 'ol::[k,ɡ]oʊɫ', 'o::ɝ[s,t]ən#', 'and#::ɫənd', 'man#::kmən', 'man#::ɫmən', 'rton::ɝtən', 'sters::stɝ', 'ight::#ɫaɪ', 'nter::#ɛnɝ', '#::[ɝ,ɹ]tən', 'rton::tən', '::[ŋ,ɝ]tən#', '::[p,ʃ]ɪŋ#', 'ing[#,t]::', '::[n,ʃ]ɪŋ#', '::[ŋ,ɝ]tən', '::[d,ʃ]ɪŋ#', 'ers[#,o]::', '::[ɝ,ɪ]sən', '::[t,ɫ]ɝz#', '::[m,t]ən#', '::[z,ʃ]ɪŋ#', '::[t,ʃ]ɪŋ#', '::[m,n]ən#', '::[ɝ,ɹ]tən', '::[ŋ,ɹ]tən', '#::ɝtən', 'hart#::', 'amtra::', '::#bitʃ', '::ŋtən#', 'lers#::', 'ing#::ə', 'sters::', '::ɹtənz', 'arb::#', 'ing#::', 'rans::', 'ingt::', 'amtr::', 'art#::', '::ɝtən', 'erso::', 'tra::#', 'and#::', 'ster::', 'der#::', '::tənz', '::ŋtən', '::ɹtən', '#::eɪɫ', 'mtra::', 'ght#::', '::#ɫaɪ', 'ters::', 'ers#::', '::ɑɹoʊ', 'ra::#', 'a::#ɡ', 'an::#', 'on#::', 'art::', 'ing::', '::#st', 'er::#', 'er#::', "'s#::", '::tən', 's#::t', '#::eɪ', '#::ɫə', 's#::ɫ', 'er::s', 'a::#t', 'al::#', '::ɫaɪ', 'or::#', 'ter::', '#::ɑɹ', '::#k', 'a::#', '::#ɡ', 'an::', '::#b', 'n::#', 'y#::', '#::n', 'r::#', 'd#::', 't#::', 'a#::', '#::ɪ', 'n#::', '::#m', '::#s', 'ta::', 'o::ɝ', 'er::', '::aɪ', 'e#::', 'l::#', 't::#', 'la::', 'ld::', '#::t', 's#::', 'in::', '::#f', '#::ɹ', '#::ə', '::ən', '#::ɫ', '::tɹ', '::st', 'r::m', '::tɪ', 't::ɫ', 'on::', 'n::ɫ', '::#', 'a::', '#::', '::w', 'l::', 'n::', '::n', 'g::', 'r::', '::f', 'd::', '::ɝ', 't::', 'e::', '::ɡ', '::k', 'o::', '::b', 'h::', '::ɛ', '::m', '::t', 's::', '::ɹ', '::ɫ', '::s', '::']
# topic 004 has 120 raw terms: ['ting# :: ɪtɪŋ#', 'lman# :: ɫmən#', 'hart# :: hɑɹt#', '#home :: #hoʊm', '#land :: #ɫænd', 'elin# :: ɪɫɪn#', 'ning# :: ənɪŋ#', 'tson# :: tsən#', 'sters :: stɝz#', 'ster# :: mstɝ#', 'derma :: ɝmən', 'rship :: ɝʃɪp', 'ever# :: ivɝ#', '#pre :: #pɹeɪ', 'light :: #ɫaɪ', "on's# :: tənz", 'mcgui :: #məɡ', 'head# :: hɛd#', 'liff# :: ɫɪf#', '#inte :: #ɪnt', '#tran :: #tɹæ', 'ing# :: əɫɪŋ#', 'ding :: ɪdɪŋ#', 'mer# :: eɪmɝ#', 'ille# :: vɪɫ#', 'lling :: ɫɪŋ#', 'amtra :: æmtɹ', 'aro# :: ɑɹoʊ#', '#stam :: stæm', 'ncy# :: ænsi#', '#arti :: #ɑɹt', 'mmel# :: məɫ#', 'eson# :: ɪsən', '#flan :: #fɫæ', 'tman :: tmən#', '#han :: #hænd', 'nders :: ændɝ', 'hing# :: ʃɪŋ#', 'tman# :: tmən', 'maste :: mæst', 'stry :: stɹi#', 'wild :: #waɪɫ', 'ving# :: vɪŋ#', 'tcher :: tʃɝ#', 'aker# :: eɪkɝ', 'lers# :: ɫɝz#', '#dis :: #dɪsk', 'ano# :: ɑnoʊ#', 'inski :: ɪnsk', 'night :: naɪt', 'ston# :: stən', 'rman :: ɹmən#', 'ing# :: ɛɹɪŋ#', '#nak :: #nɑkɑ', 'erto :: ɝtən#', 'ino# :: inoʊ#', 'land :: ɫənd#', 'ender :: ɛndɝ', 'hart :: hɑɹt#', 'ston :: stən#', 'ting :: ɪtɪŋ#', 'erton :: ɝtən', 'dness :: dnəs', 'tock :: stɑk', 'kman :: kmən', 'oman :: oʊmə', 'ide# :: aɪd#', "ton' :: ənz#", 'flan :: fɫæn', '#lan :: #ɫæn', '#mcc :: #mək', 'eck# :: bɛk#', '#fla :: #fɫæ', 'led# :: əɫd#', 'elli :: ɛɫi#', 'ton# :: tɑn#', 'sts# :: sts#', 'tal# :: təɫ#', '#con :: #kən', '#pom :: #pɑm', 'ship :: ɝʃɪp', '#sun :: #sən', 'rton :: tən#', 'ello :: ɛɫoʊ', 'beac :: #bit', 'man# :: kmən', 'ter# :: stɝ#', 'ina# :: ɪnə#', 'rton :: ɝtən', '#mit :: #mɪt', 'ker# :: ɪkɝ#', 'erto :: ɝtən', 'chit :: tʃɪt', 'ses# :: səz#', '#lin :: #ɫɪn', 'ning :: ənɪŋ', 'ende :: ɛndɝ', 'ble# :: bəɫ#', 'ert# :: pɝt#', 'tles :: əɫz#', 'mann :: mən#', 'ing# :: mɪŋ#', 'ocke :: ɑkt#', '#fre :: #fɹɛ', 'mast :: mæst', 'lers :: əɫɝz', 'are# :: wɛɹ#', 'swin :: #swɪ', 'nski :: ski#', 'star :: stɑɹ', 'hand :: hænd', '#rem :: #ɹɛm', 'rman :: dɝmə', 'ling :: ɫɪŋ#', 'tman :: mən#', 'ight :: naɪt', 'ick# :: ɹɪk#', 'elin :: ɪɫɪn', 'ess# :: tɫəs', 'term :: tɝmə']
# topic 004 found 215 locally superposed terms: ['art[#,i]::[#,h]ɑɹt', 'ing#::ɪ[d,t]ɪŋ#', 'man#::[t,ɫ]mən#', 'man[#,n]::ɫmən#', 'man#::[ɫ,ɹ]mən#', 'ster[#,s]::mstɝ', 'nders::[æ,ɛ]ndɝ', 'ing#::ə[n,ɫ]ɪŋ#', 'ting#::ɪtɪŋ#', 'man#::[k,ɫ]mən', 'man#::[t,ɫ]mən', 'man#::[k,t]mən', 'man[#,n]::kmən', 'man#::[k,ɹ]mən', 'ing::ɪ[d,t]ɪŋ#', 'ton#::[s,ɝ]tən', 'ing#::[ɫ,ʃ]ɪŋ#', 'ing#::[m,ɫ]ɪŋ#', 'ing#::[v,ɫ]ɪŋ#', 'lin#::[#,ɪ]ɫɪn', 'son#::[t,ɪ]sən', 'man::[t,ɹ]mən#', 'man[#,n]::tmən', 'man#::[t,ɹ]mən', 'no#::[i,ɑ]noʊ#', 'land::[#,f]ɫæn', 'arti::[#,h]ɑɹt', 'ing#::[m,ʃ]ɪŋ#', 'ing#::[m,v]ɪŋ#', 'hart#::hɑɹt#', 'rman::[ɝ,ɹ]mən', 'ing#::[v,ʃ]ɪŋ#', 'man#::ɫmən#', '#flan::#fɫæ', 'ton::[s,ɝ]tən', 'ing#::əɫɪŋ#', 'lin::[#,ɪ]ɫɪn', 'ning#::ənɪŋ', 'man::[k,t]mən', 'tman#::tmən', 'tman::tmən#', 'lers#::əɫɝz', 'ter[#,s]::stɝ', 'ston#::stən', 'ender::ɛndɝ', 'elin#::ɪɫɪn', 'erton::ɝtən', 'man::[k,ɹ]mən', 'lan::[#,f]ɫæn', '#land::#ɫæn', 'hand::#hænd', 'maste::mæst', 'rton::ɝtən#', 'o#::ɑ[n,ɹ]oʊ#', 'ter#::mstɝ#', 'ship::ɝʃɪp', 'flan::#fɫæ', 'ell[i,o]::ɛɫ', 'l#::[m,t]əɫ#', 'man#::kmən', 'rton::ɝtən', 'ling::ɫɪŋ#', 'sta[m,r]::st', 'ker#::eɪkɝ', 'ton#::stən', 'rman::dɝmə', 'ight::naɪt', 'ton::stən#', 'erto::ɝtən', 'erma::tɝmə', 'man::ɹmən#', '#::[b,t]əɫ#', '::t[m,s]ən#', '#::[b,m]əɫ#', 'n::[m,t]ən#', '::[s,ɝ]tən#', 'man::kmən', '::#[h,ɫ]ænd', '::[ɝ,ɫ]mən', "ton[#,']::", '::[#,ɪ]sən', '::[#,t]sən', '::[k,ɝ]mən', 'lin[#,g]::', '::[t,ɝ]mən', 'n::tmən#', 'ert[#,o]::', 'n::ɹmən#', 'ter[m,s]::', '::[s,ɝ]tən', '::[d,t]ɝmə', '::[æ,ɛ]ndɝ', 'ter[#,m]::', 'ton#::t', '#::stən', 'ing#::ə', 'n::kmən', 'n::mən#', '::tsən#', 'er#::eɪ', 'land::#', 'ocke::', 'man#::', 'ing#::', 'ton#::', 'on#::t', '::tənz', '::ɝtən', '::stən', 'tran::', "ton'::", 'ling::', '::ɝmən', 'ers#::', 'nski::', 'rman::', 'ight::', 'ess#::', 'lan::#', 'land::', '::hænd', '::stɑ', 'man::', 'er#::', 'ck#::', 'on#::', 'n#::t', '#::tə', '::tən', 's#::t', '::#mə', 'n::#s', 'an::#', 'ing::', 'le#::', '#::vɪ', 'n::#ɫ', 'in::#', 'n#::ɪ', 'rt#::', 's::əɫ', 're::#', 'ers::', '#::st', '#::əɫ', 's#::s', 'and::', '::st', 'an::', 'e#::', '#::ɪ', '#::i', 'n#::', '#::ɫ', '#::b', '::#f', '#::t', '::tə', 's#::', '::#m', 'i::#', '::#p', 'm::#', 'n::#', 'e::#', 'te::', '::ɪn', 'on::', '::ɫɪ', 'it::', '::tʃ', '::æn', '::#ɫ', '::ən', '::əɫ', '::mə', 'd::#', 'in::', '#::s', 'o#::', 'er::', 'c::#', 'd#::', '#::ə', 't::#', '::#h', '#::m', '#::h', '::s', 'k::', 'n::', '#::', '::ɪ', '::ɝ', '::ɫ', 'a::', '::#', 'i::', '::ɛ', '::t', 'm::', 'o::', 'e::', '::æ', 't::', '::ə', 's::', '::m', 'd::', '::d', 'r::', '::ɑ', '::h', '::ɹ', '::']
# topic 005 has 120 raw terms: ["rd's# :: ɑɹdz#", 'erman :: tɝmən', '#tran :: #tɹæn', '#amtr :: mtɹæk', '#wild :: waɪɫd', 'less# :: tɫəs#', 'ites# :: aɪts#', 'hart# :: hɑɹt#', 'erlin :: ɝɫɪn', 'ving# :: vɪŋ#', 'elo# :: ɛɫoʊ#', "d's# :: ɑɹdz#", 'inger :: ɪŋɝ#', 'ender :: ɛndɝ', '#bra :: #bɹæn', 'ola# :: oʊɫə#', 'den# :: ɫdən#', 'ring# :: ɝɪŋ#', 'ches# :: tʃəz', 'less# :: ɫəs#', 'rshi :: ɝʃɪp#', '#over :: oʊvɝ', '#star :: stɑɹ', '#nak :: #nɑkɑ', 'ingt :: ŋtən#', 'lock# :: ɫɑk#', 'rton# :: tən#', 'sund :: #sənd', 'ngto :: ɪŋtən', 'beach :: bitʃ', 'erma :: ɝmən#', 'ings :: ɫɪŋz#', '#bea :: #bitʃ', 'man# :: ɝmən#', 'lings :: ɪŋz#', 'righ :: ɹaɪt#', 'oman :: oʊmən', 'hand :: #hænd', '#har :: #hɑɹd', '#amt :: mtɹæk', '#mark :: #mɑɹ', '#chit :: tʃɪt', 'ble# :: bəɫ#', 'ingt :: ɪŋtə', '#lig :: #ɫaɪ', '#lif :: ɫaɪf', '#gol :: #ɡoʊ', 'stry :: tɹi#', 'ite# :: aɪt#', 'nzer :: nzɝ#', 'ter# :: ætɝ#', 'aste :: eɪst', 'ship :: ʃɪp#', 'ight :: ɹaɪt', '#mcd :: #mək', '#kor :: #kɔɹ', '#str :: #stɹ', 'ley# :: tɫi#', '#lif :: #ɫaɪ', 'life :: ɫaɪf', 'tman :: mən#', 'erto :: ɝtən', 'rds# :: ɝdz#', 'cgui :: #məɡ', 'ansk :: nski', 'ning :: nɪŋ#', '#gar :: #ɡɑɹ', '#she :: #ʃɛɹ', 'ches :: tʃəz', 'tley :: tɫi#', 'man# :: ɹmən', 'son# :: tsən', 'man# :: mæn#', 'ight :: aɪt#', '#out :: aʊtɹ', 'tman :: tmən', 'tola :: toʊɫ', 'berg :: bɝɡ#', '#war :: #wɔɹ', 'ssa# :: ɪsə#', '#din :: #dɪn', '#ran :: #ɹæn', 'fend :: fɛnd', 'nen# :: nən#', '#pel :: #pɛɫ', 'tson :: sən#', 'ting :: ɪtɪŋ', 'evit :: ɛvɪt', '#lev :: #ɫɛv', 'mtra :: tɹæk', 'ers# :: tɝz#', 'tson :: tsən', 'wate :: wɔtɝ', '#wit :: #wɪt', 'ino# :: inoʊ', 'llma :: mən#', 'acti :: æktɪ', 'ski# :: nski', 'tter :: ætɝ#', 'ona# :: ʊnə#', 'ders :: ændɝ', 'ieri :: ɪɹi#', 'ligh :: ɫaɪt', 'home :: hoʊm', 'brig :: bɹaɪ', 'ips# :: ɪps#', 'amtr :: tɹæk', '#sta :: stɑɹ', 'ing# :: nɪŋ#', '#ram :: #ɹæm', 'amtr :: mtɹæ', 'born :: bɔɹn', 'ted# :: stɪd', 'stry :: stɹi', '#vin :: #vɪn', 'ngs# :: ɪŋz#', 'ing# :: ɛɹɪŋ', 'rick :: ɹɪk#', 'mccu :: #mək', 'ood# :: wʊd#']
# topic 005 found 195 locally superposed terms: ['#li[f,g]::#ɫaɪ', 'ing#::[n,v]ɪŋ#', 'ing#::[n,ɝ]ɪŋ#', 'less#::tɫəs#', 'erman::tɝmən', 'man#::[t,ɹ]mən', 'man#::[t,ɝ]mən', 'ing#::[v,ɝ]ɪŋ#', 'ders::[æ,ɛ]ndɝ', 'man#::[ɝ,ɹ]mən', 'ight::[ɫ,ɹ]aɪt', '#amtr::mtɹæk', "d's#::ɑɹdz#", 'ship::ɝʃɪp#', 'man#::ɝmən#', 'ches#::tʃəz', 'man#::tɝmən', '#star::stɑɹ', 'ngto::ɪŋtən', 'mtra::mtɹæk', 'ings::ɫɪŋz#', 'ngs#::ɫɪŋz#', 'ight::ɹaɪt#', 'igh::[ɫ,ɹ]aɪt', 'amtr::mtɹæk', '#ra[m,n]::#ɹæ', '#lif::#ɫaɪ', 'life::ɫaɪf', 'stry::#stɹ', 'life::#ɫaɪ', 'man#::ɹmən', 'tman::tmən', 'ola#::toʊɫ', 'ing#::nɪŋ#', 'son#::tsən', 'man::tɝmən', 'ran::#tɹæn', 'tran::#tɹæ', 'tson::tsən', 'ngto::ɪŋtə', 'mtra::tɹæk', 'mtra::mtɹæ', 'ing[s,t]::ɪŋ', 'ngs#::ɪŋz#', 'amtr::mtɹæ', 'ites#::aɪt', 'ingt::ɪŋtə', 'ight::ɹaɪt', 'ight::ɫaɪt', 'n#::[n,t]ən#', 'ter#::ætɝ#', 'ligh::#ɫaɪ', 'righ::bɹaɪ', 'ley#::tɫi#', 'stry::stɹi', 'n::[m,s]ən#', '::#[b,t]ɹæn', 'ma::ɝmən#', '#st[a,r]::', '::[m,n]ən#', '::[m,t]ən#', '::[#,t]sən', '::[#,m]tɹæ', '::[t,ɝ]mən', '::[n,s]ən#', '::[s,t]ən#', '::[m,s]ən#', '::[ɝ,ɹ]mən', '::[t,ɪ]ɹi#', 'ing[#,t]::', 'ing[#,s]::', 'ing[s,t]::', '::[ŋ,ɝ]tən', '#star::', 'man#::m', '::ɝmən#', '::mtɹæk', '::#bitʃ', 'ings::ɪ', 'ingt::ɪ', '::ɹaɪt#', '::ŋtən#', '::#bɹæn', '::#mək', 'stry::', '::#ɫaɪ', '::mən#', 'ingt::', 'ings::', 'ing#::', 'on#::t', 'man#::', '::#tɹæ', '::tmən', '::fɛnd', '::#sən', '::hoʊm', '::ɹaɪt', '::ɫaɪt', '::#hɑɹ', '::aɪt#', '::ɹmən', '::ɝtən', 'ers#::', '::nski', '::bɹaɪ', '::ɫaɪ', '::#mə', 'man::', 'ing::', 'ar::#', 'in::#', 'nd::#', 's#::ɪ', 'a::#b', 'es#::', '::aɪt', 'en#::', 's#::t', '#::tɫ', 'e#::', 'in::', '::#ɡ', 'l::#', 'o#::', '#::ɛ', 'er::', 's#::', 'd::#', '::#m', 'r::#', 'tr::', '::#s', '::#ɫ', 'an::', '::ɪŋ', '#::ɝ', '::oʊ', 'a#::', 'ar::', '::tʃ', '#::ɫ', '#::t', 'n#::', '::tɝ', 'n::t', 'n::#', '::st', '::#w', '#::ɪ', 'k::#', 'nd::', 'it::', 'to::', '::tɹ', 'ra::', 'a::t', '#::n', 'd#::', 'te::', 't::a', 'g::b', '::tɫ', '::#h', 'ig::', 'y::t', '#::', '::b', 'n::', '::ɝ', '::ɫ', '::#', '::ɛ', 'r::', '::n', 'd::', '::m', '::ɪ', 'g::', 'e::', '::t', 's::', 'i::', '::s', 'k::', 't::', 'a::', 'h::', '::æ', '::h', '::a', '::ɹ', '::w', 'y::', '::']
# topic 006 has 120 raw terms: ['#ligh :: #ɫaɪt', 'erman :: ɝmən#', 'light :: #ɫaɪt', 'ders# :: ndɝz#', '#amtr :: #æmtɹ', 'ingto :: ɪŋtən', 'right :: ɹaɪt#', '#over :: oʊvɝ', 'righ :: ɹaɪt#', "ton's :: ɹtən", '#hom :: #hoʊm', 'aster :: æstɝ', 'iness :: inəs', 'rton :: ɹtənz', 'mster :: stɝ#', 'enter :: #ɛnɝ', 'ino# :: inoʊ#', 'chit :: #tʃɪt', 'ing# :: ɪtɪŋ#', 'sand :: #sænd', 'erson :: ɝsən', 'aster :: mæst', 'man# :: kmən#', '#over :: #oʊv', 'nsky# :: nski', 'tion# :: ʃən#', '#sca :: #skɛɹ', 'auer# :: aʊɝ#', 'ers# :: əɫɝz#', 'ming# :: mɪŋ#', 'art# :: ɪnhɑɹ', 'ying# :: ɪɪŋ#', 'ston# :: stən', 'ender :: ɛndɝ', 'ever# :: ivɝ#', 'fford :: fɝd#', 'ness :: dnəs#', 'man# :: ɫmən#', 'ling :: əɫɪŋ#', 'hand :: #hænd', 'ness# :: dnəs', 'lson# :: ɫsən', 'sund :: #sənd', 'less :: tɫəs#', 'nick# :: nɪk#', 'derm :: dɝmən', '#van :: #væn', '#mel :: #mɛɫ', '#gen :: dʒɛn', 'mtra :: æmtɹ', '#ran :: ɹæns', 'mann :: mən#', '#gal :: #ɡəɫ', 'ning :: ənɪŋ', '#tom :: #toʊ', 'man# :: kmən', 'ites :: ɪts#', 'ton# :: tən#', 'ster :: stɝz', 'step :: stɛp', 'allo :: æɫoʊ', '#cam :: #kæm', '#her :: #hɛɹ', '#wil :: #waɪ', 'ckma :: kmən', 'own# :: aʊn#', 'inte :: #ɪnt', 'les# :: əɫz#', 'weis :: #waɪ', '#col :: #koʊ', 'cher :: tʃɝ#', 'mtra :: mtɹæ', '#pre :: #pɹe', 'ard# :: ɑɹd#', 'ted# :: tɪd#', 'sion :: ɪʒən', 'vand :: #væn', 'ing# :: dɪŋ#', "ton' :: tənz", 'ess# :: nəs#', 'its# :: ɪts#', 'art# :: ɪnhɑ', 'ming :: ɪmɪŋ', 'ranc :: ɹæns', '#tra :: tɹeɪ', 'wild :: #waɪ', 'berg :: nbɝɡ', '#tom :: toʊm', 'life :: #ɫaɪ', 'toma :: #toʊ', '#fel :: #fɛɫ', '#dor :: #dɔɹ', '#deb :: #dɛb', 'ding :: dɪŋ#', '#wal :: #wɔk', 'kman :: kmən', 'cour :: #kɔɹ', 'lman :: mən#', '#jer :: #dʒɛ', 'bric :: bɹɪk', '#bra :: #bɹæ', 'lodg :: ɫɑdʒ', 'hes# :: ʃəz#', '#gin :: #ɡɪn', 'ncy# :: ænsi', 'dget :: dʒɪt', 'ting :: ɪtɪŋ', '#wei :: #waɪ', "r's# :: tɝz#", 'ande :: #væn', '#pre :: pɹeɪ', 'eson :: ɪsən', 'gle# :: ɡəɫ#', 'der# :: aɪdɝ', 'sive :: sɪv#', 'rock :: #ɹɑk', 'ngto :: ɪŋtə', 'nzo# :: zoʊ#', 'boar :: bɔɹd', '#rad :: #ɹæd']
# topic 006 found 196 locally superposed terms: ['man[#,n]::kmən#', 'man[#,n]::ɫmən#', 'man#::[k,ɝ]mən#', 'man#::[k,ɫ]mən#', 'man#::[ɝ,ɫ]mən#', 'ness#::[d,i]nəs', 'light::#ɫaɪt', 'man[#,n]::kmən', 'and::#[h,s]ænd', 'son#::[ɝ,ɫ]sən', 'ing#::[d,m]ɪŋ#', 'ing#::[d,ɪ]ɪŋ#', 'man#::[k,ɫ]mən', 'ing#::[m,ɪ]ɪŋ#', 'ton#::[s,ɹ]tən', "ton[#,']::stən", 'ness::[d,i]nəs', 'man#::[k,ɝ]mən', 'son#::[ɪ,ɫ]sən', 'right::ɹaɪt#', 'mtra::#æmtɹ', 'aster::mæst', 'ing#::ɪtɪŋ#', 'ess#::dnəs#', 'ming#::ɪmɪŋ', 'son::[ɝ,ɪ]sən', 'man#::kmən#', 'man::[k,ɝ]mən', '#over::#oʊv', 'on#::[t,ʃ]ən#', 'ness#::dnəs', "ton's::ɹtən", "ton'::ɹtənz", "ton[#,']::tən", 'man#::ɫmən#', 'vand::#væn', 'mtra::æmtɹ', '#tom::#toʊ', 'toma::#toʊ', 'ste[p,r]::st', 'ster::æstɝ', 'wild::#waɪ', 'weis::#waɪ', '#pre::#pɹe', 'ngto::ɪŋtə', 'ing#::ɪtɪŋ', 'ess#::inəs', 'ess#::dnəs', 'man#::kmən', 'ing#::dɪŋ#', 'kman::kmən', 'ton#::stən', 'ande::#væn', 'ranc::ɹæns', 'man::ɝmən#', 'ton#::ɹtən', 'art#::ɪnhɑ', 'ster::stɝ', 'man::kmən', 'n::ɝmən#', '::[m,t]ən#', '::[m,ʃ]ən#', 'ste[p,r]::', 'les[#,s]::', '::[p,t]ɹeɪ', '::[#,ɝ]sən', '::[s,ɹ]tən', 'der[#,m]::', '#ra[d,n]::', '::[#,ɪ]sən', '::[#,ɫ]sən', '::[k,ɝ]mən', '::[k,ɫ]mən', 'n::kmən', 'n::mən#', 'nter::#', 'ing#::ɪ', 'ande::#', 'ders#::', '::dɝmən', '::#væn', 'ight::', '::#ɫaɪ', '::kmən', 'ing#::', 'ing::ə', '::ɪts#', 'ster::', '::stɝz', '::#waɪ', 's#::əɫ', 'mtra::', 'ion#::', 'ess#::', 'and::#', 'nd::#s', 'ing::ɪ', 'ver#::', '::#dʒɛ', '::ɹæns', 'er#::a', 'der#::', '::#ɡəɫ', '::ɹtən', '::ɛndɝ', 'nder::', 'derm::', 'ers#::', 'el::#', 'igh::', 'tra::', 'ing::', 'om::#', 'ter::', 'l::#w', '#::aʊ', 'es#::', 'her::', 'on::ɪ', 'er::#', '#::ɪt', 's#::n', 'r::#d', '#::ʃə', 'on#::', 'er#::', 'ess::', 'nd::#', 'al::#', 'n#::ɫ', 'an::', 'n::#', 'l::#', 'ra::', 'm::#', '::#t', '::ɪt', 'er::', '::st', 't::#', '::#h', 'om::', 'n#::', '#::a', 's#::', '::əɫ', '::#w', 'e::#', 'r::#', 'on::', '#::ɪ', '#::n', 'd::#', '::#s', 'n::ɝ', 'ma::', 'a::#', '::#d', '::#ɡ', 'y#::', '::dʒ', '#::t', '#::i', '::#ɹ', '::#k', 'd#::', '#::d', 'n::ɹ', 'o#::', '::in', '::#', 'n::', '::æ', 'a::', '::m', '::ə', 'g::', 'm::', 's::', '::ɪ', 'r::', '::s', 't::', '#::', '::t', 'e::', 'o::', '::n', 'd::', '::d', '::ɫ', '::i', '::ɹ', 'c::', '::b', '::']
# topic 007 has 120 raw terms: ['gton# :: ŋtən#', '#hand :: #hænd', 'dness :: dnəs#', 'derma :: ɝmən#', 'land# :: ɫənd#', 'nsky# :: nski#', 'ters# :: stɝz#', 'line# :: aɪn#', 'amtra :: mtɹæ', 'ande :: #vænd', 'son# :: tsən#', '#home :: hoʊm', '#miss :: #mɪs', 'ton# :: ɝtən#', "ard's :: ɹdz#", 'mann# :: mən#', 'ston# :: tən#', 'itch# :: ɪtʃ#', 'ider :: aɪdɝ#', 'aro# :: ɑɹoʊ#', 'ight# :: ɹaɪt', 'aker# :: eɪkɝ', '#carb :: #kɑɹ', 'well# :: wɛɫ#', 'stry# :: stɹi', '#toma :: #toʊ', 'flan :: #fɫæn', "an's# :: ənz#", 'ski# :: nski#', 'ling :: ɫɪŋz#', 'tman :: tmən#', 'idge# :: ɪdʒ#', 'lers# :: əɫɝz', 'rman# :: ɝmən', 'illin :: ɪɫɪŋ', 'ing# :: ɪdɪŋ#', 'stock :: stɑk', '#cas :: #kæsə', '#flas :: #fɫæ', 'hart :: hɑɹt#', 'gert# :: ɡɝt#', 'der# :: aɪdɝ#', 'lman# :: ɫmən', '#tra :: #tɹeɪ', 'scar :: #skɛɹ', 'rman :: ɝmən#', '#wild :: waɪɫ', '#ligh :: #ɫaɪ', 'inter :: ɪntɝ', '#inte :: #ɪnt', '#bea :: #bitʃ', 'right :: ɹaɪt', 'nsky :: nski', 'derm :: mən#', 'man# :: ɫmən', 'lden :: dən#', 'cio# :: ioʊ#', 'tche :: tʃɝ#', 'sky# :: nski', '#ove :: #oʊv', '#gol :: #ɡoʊ', 'oggl :: ɑɡəɫ', 'nce# :: əns#', 'one# :: oʊni', 'kman :: kmən', 'ven# :: vən#', 'tic# :: tɪk#', 'ker# :: ɪkɝ#', '#int :: #ɪnt', '#gra :: #ɡɹæ', '#cas :: kæsə', 'vill :: vɪɫ#', '#boe :: #boʊ', 'eck# :: bɛk#', 'guar :: ɡɑɹd', 'and# :: ɫənd', 'cass :: #kæs', 'ter# :: ɪstɝ', '#dow :: #daʊ', '#mis :: #mɪs', 'ring :: ɝɪŋ#', '#col :: koʊɫ', 'barb :: bɑɹb', 'iff# :: ɫɪf#', '#gow :: #ɡaʊ', 'nds# :: ɫənd', 'rans :: ɹæns', '#sou :: #saʊ', 'tman :: tmən', 'derm :: dɝmə', 'down :: daʊn', 'dnes :: dnəs', 'ness :: dnəs', '#pom :: #pɑm', '#sta :: stæm', 'tola :: toʊɫ', 'hes# :: ʃɪz#', 'ster :: mstɝ', 'lers :: əɫɝz', 'fran :: #fɹæ', '#san :: sænd', 'ver# :: ivɝ#', 'rton :: ɝtən', 'naka :: #nɑk', 'flan :: fɫæn', 'ente :: #ɛnɝ', '#tra :: #tɹe', '#bri :: #bɹɪ', 'sion :: ɪʒən', 'ster :: tɝz#', 'ted# :: tɪd#', '#dis :: #dɪs', 'bian :: biən', 'ara# :: ɑɹə#', 'scar :: #skɛ', 'erli :: ɝɫɪn', 'son# :: ɫsən', 'ser# :: ɪsɝ#', 'etti :: ɛti#', 'ing# :: #aʊt']
# topic 007 found 186 locally superposed terms: ['ande::#[h,v]ænd', 'ton#::[ŋ,ɝ]tən#', 'son#::[t,ɫ]sən', 'fla[n,s]::#fɫæ', 'man#::[t,ɫ]mən', 'man#::[t,ɝ]mən', 'man#::[k,ɫ]mən', 'man#::[ɝ,ɫ]mən', 'ton#::[ŋ,ɝ]tən', 'man::[t,ɝ]mən#', 'ter#::[m,ɪ]stɝ', 'man#::[k,ɝ]mən', 'derma::ɝmən#', 'nsky#::nski', '#miss::#mɪs', 'ton#::ɝtən#', '#inte::#ɪnt', '#cas::#kæsə', 'flan::#fɫæn', 'dness::dnəs', 'man::[k,t]mən', 'man::[t,ɝ]mən', 'derma::dɝmə', 'man::[k,ɝ]mən', 'rman#::ɝmən', 'rman::ɝmən#', 'inter::#ɪnt', 'ton#::ŋtən#', 'der#::aɪdɝ#', 'ight#::ɹaɪt', 'ters#::ɪstɝ', 'lers#::əɫɝz', 'sky#::nski', 'on#::tsən#', 'ton#::ɝtən', 'n#::[m,t]ən#', 'n#::[m,v]ən#', 'n#::[t,v]ən#', 'ker#::eɪkɝ', 'ling::ɪɫɪŋ', 'down::#daʊ', '#go[l,w]::#ɡ', 'ness::dnəs', 'tman::tmən', 'man#::ɫmən', 'scar::#skɛ', 'and#::ɫənd', '#tra::#tɹe', '::t[m,s]ən#', '::ɝ[m,t]ən#', '::[t,ɝ]mən#', 'and[#,e]::', '::[d,m]ən#', '::[d,t]ən#', '::[d,v]ən#', 'tch[#,e]::', 'n#::ɫmən', 'n#::ɝmən', '::[m,v]ən#', '::[t,ɝ]mən', 'der[#,m]::', '::[k,t]oʊɫ', '::[ɝ,ɫ]mən', '::[m,t]ən#', '#::nski#', '::[k,ɝ]mən', '::tmən#', '::ɝmən#', 's::#kæs', '#::ɫənd', 's::dnəs', 'a::#toʊ', 'carb::#', 'ter#::ɪ', 'er#::ɪs', '#::nski', '::stɝz#', '::nski', '::mən#', '::kmən', '::tmən', 'er#::ɪ', '::#ɪnt', 'an::#f', 'ing#::', 'derm::', '::dɝmə', 'rans::', '::ɫmən', 'and#::', 'nte::#', 'ter#::', '::ɝmən', 'ers#::', 'ight::', 'nter::', 'ster::', '::mstɝ', 'ne#::', '#::aɪ', 'on#::', 'ss::#', 'n#::ɝ', '#::tɪ', 'er#::', '#::st', '#::ən', 's#::ə', 'ing::', 'ow::#', 'arb::', 'as::#', 'n#::ɫ', 'is::#', 'tra::', '#::ɪd', 'ra::#', 'a::#t', 'ter::', '#::ɑɹ', 'e#::', '::aɪ', 'e::#', 'n::d', 'n#::', '#::t', 'ss::', 's::#', '#::ɪ', 'as::', 'y#::', '::st', 'an::', 's#::', '::#b', 'ar::', '::#k', '::ɫɪ', '::#d', '::#ɡ', '#::ɫ', '::#s', 'n::ɪ', '::#f', 't#::', 'n::ɝ', 'on::', 'd#::', 'a::#', 'ra::', 'o#::', '#::i', 'ol::', '#::ə', 'er::', 's::ɹ', 'ma::', '#::', 'e::', '::#', 'n::', '::d', '::t', 'l::', '::ɑ', 's::', '::ɝ', '::m', '::ɪ', '::v', 't::', '::w', '::k', '::s', '::ə', 'r::', '::ɡ', '::ɫ', '::b', 'm::', 'a::', '::h', 'd::', 'i::', '::ɹ', '::']
# topic 008 has 120 raw terms: ['#flan :: #fɫæn', "rd's# :: ɑɹdz#", 'lman# :: ɫmən#', 'nski# :: nski#', '#ligh :: #ɫaɪt', 'nnon# :: ænən#', '#bran :: #bɹæn', '#stor :: #stɔɹ', 'ites# :: aɪts#', 'gton# :: ɪŋtən', 'lson# :: ɫsən#', 'ship# :: ɝʃɪp#', 'rrow# :: ɹoʊ#', 'flan :: #fɫæn', 'ingto :: tən#', 'nick# :: nɪk#', 'ing# :: ɪtɪŋ#', 'mtra :: #æmtɹ', 'art# :: hɑɹt#', "ay's# :: eɪz#", '#gol :: #ɡoʊɫ', 'ckman :: kmən', 'gton# :: tən#', 'nzer# :: nzɝ#', '#cra :: #kɹeɪ', 'tson# :: tsən', 'rman# :: mən#', 'oted# :: tɪd#', 'eson :: ɪsən#', "ard' :: ɑɹdz#", 'ansk :: nski#', 'atter :: ætɝ#', 'down :: #daʊn', 'sner# :: snɝ#', '#nak :: #nɑkɑ', '#back :: #bæk', 'lman :: ɫmən#', 'nsky# :: nski', 'ider# :: aɪdɝ', '#bran :: bɹæn', 'mast :: mæstɝ', 'ness# :: inəs', 'terma :: tɝmə', 'lson# :: sən#', '#stor :: #stɔ', 'rshi :: ɝʃɪp#', 'illin :: ɪɫɪŋ', '#wild :: #waɪ', '#mast :: #mæs', "ter's :: tɝz#", 'ders# :: ndɝz', 'eson# :: ɪsən', 'hart# :: nhɑɹ', 'chey# :: tʃi#', 'eck# :: bɛk#', '#far :: #fɑɹ', 'flan :: #fɫæ', 'red# :: tɝd#', 'ard# :: wɝd#', 'wild :: waɪɫ', 'west :: wɛst', 'gged :: æɡd#', '#han :: hænd', 'ande :: vænd', '#bru :: #bɹu', 'ight :: ɫaɪt', 'kel# :: ɪkəɫ', 'tran :: #tɹæ', 'nder :: ændɝ', 'ses# :: sɪz#', 'ward :: wɝd#', 'win# :: wɪn#', 'her# :: tʃɝ#', 'isio :: ɪʒən', 'ieri :: ɪɹi#', 'sses :: sɪz#', 'over :: #oʊv', 'eman :: mən#', 'ings :: ɪŋz#', 'ino# :: noʊ#', '#bar :: bɑɹb', 'gton :: ɪŋtə', 'ess# :: ɫəs#', 'ham# :: həm#', '#gin :: #ɡɪn', 'unds :: ndz#', 'ona# :: oʊnə', 'erso :: sən#', 'evit :: vɪt#', '#hei :: #haɪ', '#pen :: #pɛn', '#pro :: #pɹo', 'auer :: aʊɝ#', 'ridg :: ɹɪdʒ', 'ota# :: ʊtə#', '#mcd :: məkd', 'ngto :: tən#', 'try# :: tɹi#', 'sek# :: sɛk#', 'pert :: pɝt#', 'toma :: #toʊ', 'nsky :: ski#', 'road :: ɹoʊd', 'ead# :: hɛd#', 'anno :: ænən', 'swin :: #swɪ', 'ips# :: ɪps#', 'tion :: ʃən#', 'ridg :: ɪdʒ#', '#fan :: #fæn', 'ster :: stɝ#', 'lin# :: ɫɪn#', 'atle :: tɫi#', '#sto :: #stɔ', 'ding :: ɪdɪŋ', '#coa :: #koʊ', 'shin :: ʃɪŋ#', 'ler# :: sɫɝ#', 'nski :: ski#', 'stam :: stæm']
# topic 008 found 183 locally superposed terms: ['nsk[i,y]#::nski', 'son#::[ɪ,ɫ]sən#', 'son#::[t,ɪ]sən', 'son#::[t,ɫ]sən', '#bran::#bɹæn', 'nsk[i,y]::ski#', 'lson#::ɫsən#', 'son#::[ɪ,ɫ]sən', 'nski#::nski#', 'man#::[k,ɫ]mən', 'lman#::ɫmən#', 'flan::#fɫæn', 'ight::#ɫaɪt', 'on#::[s,t]ən#', 'man#::ɫmən#', 'nsky::nski#', 'nski::nski#', 'ter::[s,æ]tɝ#', '#stor::#stɔ', 'nsky#::nski', 'gton#::ɪŋtə', 'son#::ɪsən#', 'eson#::ɪsən', 'n#::ɫ[m,s]ən#', 'man::[k,ɫ]mən', 'in#::[w,ɫ]ɪn#', 'k#::[b,s]ɛk#', 'flan::#fɫæ', 'd#::[t,w]ɝd#', 'ard#::wɝd#', 'nder::vænd', 's#::[e,s]ɪz#', 'n#::[m,t]ən#', 'ses#::sɪz#', 'son#::tsən', 'man#::mən#', 'man::ɫmən#', 'ridg::ɹɪdʒ', '#fa[n,r]::#f', 'n#::[m,s]ən#', 'son#::ɪsən', 'mast::#mæs', 'wild::#waɪ', 'art#::nhɑɹ', 'man#::kmən', 'ngto::tən#', '#::[n,ɹ]oʊ#', 'ing[#,s]::ɪ', 'man::kmən', 'n::[m,ʃ]ən#', 'o::[s,t]ən#', '::ɫ[m,s]ən#', "ard[#,']::", '::[h,v]ænd', '::[e,s]ɪz#', '::[m,t]ən#', '::[s,t]ən#', '::[t,ʃ]ən#', '::[t,w]ɝd#', '::[t,ɪ]ɹi#', '::[m,s]ən#', '::[m,ʃ]ən#', '::[s,ʃ]ən#', 'ers[#,o]::', 'ing#::ɪ', 'tran::#', 'gton#::', '::ɑɹdz#', '::nski#', '::ɝʃɪp#', 'ders#::', '::ɪsən#', 'ings::ɪ', '::ɫsən#', 'an::#f', '::ɫaɪt', '::hænd', 'der#::', '::ændɝ', '::tən#', 'on#::t', '::tsən', "ard'::", 'ed#::t', '::nski', 'ess#::', 'ran::#', 'on#::ɪ', 'win#::', '::sən#', '::ɪsən', 'shin::', 'gton::', 'er#::s', '::ænən', 'lin#::', 'ck#::', '::ɹoʊ', 'an::#', 'ra::#', "'s#::", 'er::æ', 'on#::', 'es#::', 'er#::', '#::tʃ', 'in::#', '::#bɹ', 'y#::t', '#::aɪ', 'a::#k', 'ran::', 'on::ɪ', 'g::ɪd', 'n#::ɫ', '::#f', 'an::', 'n::#', '#::w', 'd#::', '#::n', 'k#::', 'st::', '#::ɪ', 'a::#', 's#::', '::#ɡ', 'er::', '::æn', '#::t', 'n#::', '#::s', 'd::w', '::mə', 'ar::', '#::ɫ', '#::h', 'in::', 'a#::', '::#b', 'r::#', '::#s', 'y#::', '::ɪŋ', 'on::', 'n::ʃ', 'to::', 'o::#', '::nd', '::tɝ', '::#t', 'n::ɪ', 'k::#', '::#p', '::st', 'ma::', '#::', '::b', '::ɹ', '::#', 'n::', '::w', '::n', 't::', '::v', 'e::', '::ɪ', '::ɫ', 'a::', 'r::', '::æ', '::t', '::s', 'd::', 'i::', 's::', '::m', 'k::', '::h', '::a', 'g::', 'o::', '::']
# topic 009 has 120 raw terms: ['#home :: #hoʊm', 'hart# :: nhɑɹt', 'lings :: ɫɪŋz#', '#flan :: #fɫæn', '#stam :: #stæm', 'beach :: #bitʃ', 'rton# :: ɝtən#', 'ence# :: əns#', '#galo :: #ɡəɫ', '#home :: #hoʊ', 'ola# :: oʊɫə#', 'ster# :: ɪstɝ', 'gton# :: tən#', '#chit :: tʃɪt', 'lden# :: dən#', '#stor :: stɔɹ', 'kman# :: kmən', 'ding :: ɪdɪŋ#', 'and# :: ɫənd#', 'ight# :: ɹaɪt', '#stam :: stæm', 'ota# :: oʊtə#', '#sta :: #stæm', '#beac :: bitʃ', 'ashi# :: ɑʃi#', 'water :: wɔtɝ', 'led# :: təɫd#', 'light :: ɫaɪt', 'llman :: ɫmən', 'shing :: ʃɪŋ#', '#hom :: #hoʊm', 'ight :: #ɫaɪt', 'dness :: dnəs', "o's# :: koʊz#", 'stor :: #stɔɹ', "ard' :: ɑɹdz#", 'ski# :: nski#', '#cass :: kæsə', 'ance# :: æns#', 'eman# :: mən#', "on's# :: ɹtən", 'ckman :: kmən', 'lson# :: sən#', 'well# :: wɛɫ#', 'lden# :: ɫdən', 'ingt :: ɪŋtən', 'tter# :: ætɝ#', 'ness :: dnəs#', 'ites# :: ɪts#', 'mark :: #mɑɹk', 'ker# :: eɪkɝ#', 'ridge :: ɪdʒ#', '#car :: #kɑɹb', 'tes# :: aɪts#', 'odge :: ɫɑdʒ', '#mai :: #meɪ', 'lin# :: ɫɪn#', '#cam :: #kæm', 'nzer :: nzɝ#', '#mcn :: məkn', 'sion :: ɪʒən', '#har :: hɑɹd', 'ming :: ɪmɪŋ', 'walk :: #wɔk', 'mtra :: #æmt', 'ics# :: ɪks#', '#out :: #aʊt', 'ess# :: nəs#', '#mck :: #mək', 'ing# :: ɛɹɪŋ', '#bed :: #bɛd', 'hip# :: ʃɪp#', 'ich# :: ɪtʃ#', '#boe :: #boʊ', 'cour :: #kɔɹ', 'nski :: ski#', 'ine# :: ɫaɪn', '#wil :: waɪɫ', '#cou :: #kɔɹ', 'ley# :: sɫi#', 'son# :: tsən', 'zer# :: nzɝ#', '#ove :: #oʊv', '#hol :: #hɑɫ', 'cked :: ɑkt#', '#amt :: æmtɹ', 'elo# :: ɫoʊ#', 'lock :: ɫɑk#', '#sto :: stɔɹ', 'scar :: #skɛ', 'ally :: əɫi#', 'ard# :: ɑɹd#', 'rson :: sən#', 'rton :: tən#', "d's# :: ɑɹdz", 'ight :: ɹaɪt', '#gal :: #ɡəɫ', '#tru :: #tɹu', 'ino# :: inoʊ', 'barb :: bɑɹb', 'ing# :: ʃɪŋ#', 'lli# :: ɛɫi#', '#sha :: #ʃæt', 'ned# :: ənd#', 'ing# :: vɪŋ#', 'rman :: tɝmə', 'ing# :: tɪŋ#', 'cart :: kɑɹt', '#fir :: #fɝm', 'fers :: fɝz#', 'mccu :: #mək', 'lers :: əɫɝz', 'ing# :: ɪdɪŋ', '#har :: #hɑɹ', '#lar :: #ɫɑɹ', 'ggle :: ɡəɫ#', 'sund :: sənd', '#tom :: #toʊ', 'ding :: dɪŋ#', 'iff# :: ɫɪf#']
# topic 009 found 202 locally superposed terms: ['ight#::[ɫ,ɹ]aɪt', 'nce#::[æ,ə]ns#', '#home::#hoʊm', '#mc[k,n]::#mək', 'man#::[k,ɫ]mən', '#stam::#stæm', 'beach::#bitʃ', 'ing#::[v,ʃ]ɪŋ#', 'ing#::[t,ʃ]ɪŋ#', 'ing#::[d,ʃ]ɪŋ#', 'ing#::[t,v]ɪŋ#', 'ing#::[d,t]ɪŋ#', 'rton#::ɝtən#', 'ing#::[d,v]ɪŋ#', 'ight::[ɫ,ɹ]aɪt', '#home::#hoʊ', 'lden#::ɫdən', 'kman#::kmən', 'ding::ɪdɪŋ#', 'ight#::ɹaɪt', 'ing::[d,ʃ]ɪŋ#', 'stor::#stɔɹ', "ard[#,']::ɑɹd", 'ski#::nski#', 'man::[k,ɫ]mən', 'ess#::dnəs#', 'ton#::ɝtən#', 'on#::[s,t]ən#', 'ight::#ɫaɪt', '#stor::stɔɹ', '#galo::#ɡəɫ', 'tes#::aɪts#', '#ca[m,r]::#k', '#har::#hɑɹ', 'n#::[d,t]ən#', 'n#::[d,m]ən#', 'n#::[d,s]ən#', 'man#::kmən', 'ing#::ɪdɪŋ', 'cour::#kɔɹ', 'zer#::nzɝ#', 'ing#::ʃɪŋ#', 'son#::tsən', 'on::[s,t]ən#', 'son#::sən#', 'cart::#kɑɹ', 'ness::dnəs', 'ton#::tən#', 'n#::[m,t]ən#', '#ho[l,m]::#h', 'man#::ɫmən', 'n#::[m,s]ən#', 'ess#::dnəs', 'd#::ɫənd#', '#::[s,ɛ]ɫi#', '#::[ɝ,ɹ]tən', 'ing[#,t]::ɪ', '::[d,s]ən#', '::[d,t]ən#', '::[s,ɫ]ənd', '::[#,n]hɑɹ', '::[s,ə]ɫi#', '::[s,t]ən#', '::[m,s]ən#', 'ing[#,s]::', 'ing[#,t]::', 'ing[s,t]::', '#st[a,o]::', '::[ə,ɛ]ɫi#', '::[m,t]ən#', 'ing#::ɪ', 'ingt::ɪ', 'ight#::', '#::ɹaɪt', '#::ɹtən', 'ter#::', '::#mək', '::nhɑɹ', '::hɑɹd', 'ing::ɪ', 'ing#::', 'ings::', 'man#::', 'art#::', '::#ɫaɪ', 'ingt::', 'cart::', 'car::#', '::ɑɹdz', '#::ɑɹd', '::ɹtən', '::#ɡəɫ', 'a#::oʊ', 'on#::t', '::#æmt', '::tsən', 'ight::', '::sənd', '::ɫaɪt', '::ɹaɪt', 'dge::', '#::ən', 'er#::', 'am::#', 'ing::', 'k::#m', '#::ɪt', 'r::#k', '::ɫaɪ', '#::tə', 'ed#::', "'s#::", 'r::#s', 'ar::#', '::#st', '::sən', '#::ʃɪ', 'man::', 'ers::', 'n#::ɫ', '::#hɑ', 'on#::', 'om::#', 's#::ɪ', '#::ɫɪ', '::ɫɑ', 'e#::', 'e::#', '::#h', '#::ɪ', 'am::', '::#k', 'm::#', '::mə', 'ar::', 'n#::', '#::k', '::ɪd', '#::ɫ', 'd#::', 't#::', '#::ɹ', '::#m', 'k::#', 'ck::', '::st', '::#b', 'ed::', '#::n', 'r::#', 'er::', '#::t', '::tə', '#::s', 'o#::', '::ʃɪ', 'an::', '::#f', 's#::', '::#s', 'on::', '#::ɑ', 'i#::', 'u::#', '::#t', 'a::#', '#::æ', 'ss::', 't::#', '#::ɛ', '::ɫɪ', 'l::#', '::#ɫ', '::əɫ', 'n::t', 'e::', '::ɫ', '#::', '::ə', '::#', '::ɪ', 'n::', 'r::', '::d', '::k', '::s', 'm::', 'd::', '::n', '::b', '::w', '::t', '::ɑ', 'k::', '::æ', '::ɹ', 't::', 's::', 'i::', 'l::', 'o::', '::']
# topic 010 has 120 raw terms: ['ders# :: ndɝz#', 'terma :: tɝmən', "rd's# :: ɑɹdz#", "ton's :: ɹtənz", '#over :: #oʊvɝ', 'feld# :: fɛɫd#', '#outr :: #aʊtɹ', 'ship# :: ɝʃɪp#', 'lland :: ɫənd#', 'ness# :: inəs#', 'ters# :: stɝz#', '#scar :: #skɛɹ', 'ton# :: ɝtən#', '#wil :: #waɪɫ', '#back :: #bæk', 'ers# :: stɝz#', 'ship# :: ɝʃɪp', 'dge# :: ɹɪdʒ#', 'owski :: ski#', '#mcgu :: #məɡ', 'ship :: ɝʃɪp#', 'ncy# :: ænsi#', 'mtra :: #æmtɹ', 'night :: naɪt', "n's# :: tənz#", '#cass :: #kæs', 'erma :: ɝmən#', "rton' :: tənz", '#beac :: bitʃ', 'ford# :: fɝd#', 'beach :: #bit', 'ines :: inəs#', 'hand :: #hænd', 'erso :: ɝsən#', 'erson :: sən#', 'born :: bɔɹn#', 'hart# :: ɪnhɑ', 'land# :: ɫənd', 'inter :: ɪntɝ', 'nski# :: nski', '#stam :: stæm', 'try# :: stɹi#', 'rman :: ɝmən#', '#hom :: #hoʊm', 'gton# :: ɪŋtə', '#bra :: #bɹæn', 'ingt :: ŋtən#', "ay's# :: eɪz#", 'stock :: stɑk', 'ight :: ɹaɪt#', '#naka :: nɑkɑ', 'ring# :: ɝɪŋ#', 'ieri# :: ɪɹi#', "rton' :: ənz#", '#flas :: #fɫæ', '#home :: #hoʊ', 'hing# :: ʃɪŋ#', 'erlin :: ɝɫɪn', 'ers# :: ndɝz#', '#boh :: #boʊ', 'ive# :: sɪv#', 'term :: tɝmə', '#dor :: #dɔɹ', 'ers# :: fɝz#', 'ster :: tɝz#', '#sta :: stɑɹ', 'ande :: #væn', 'mail :: meɪɫ', 'ferr :: fɛɹə', 'als# :: əɫz#', '#tra :: tɹeɪ', 'mark :: mɑɹk', '#spi :: #spɪ', 'revi :: #ɹiv', '#bra :: bɹæn', 'term :: ɝmən', 'ndon :: ndən', 'erg# :: bɝɡ#', '#man :: #mæn', 'nter :: #ɛnɝ', 'ming :: ɪmɪŋ', '#est :: #ɛst', 'ked# :: ɑkt#', 'etta :: ɛtə#', '#min :: #maɪ', 'ven# :: vən#', 'son# :: ɫɪsə', 'mcgu :: #məɡ', 'ona# :: ʊnə#', 'life :: ɫaɪf', 'ger# :: ɪŋɝ#', 'amtr :: tɹæk', '#sna :: #snæ', '#bra :: #bɹæ', 'herr :: #ʃɛɹ', '#lif :: #ɫaɪ', '#amt :: æmtɹ', 'gged :: æɡd#', 'sner :: snɝ#', 'sund :: sənd', 'lass :: kɫæs', 'try# :: stɹi', 'mtra :: tɹæk', 'ingt :: tən#', 'tion :: ʃən#', '#sou :: #saʊ', 'tle# :: təɫ#', 'ata# :: ɑtə#', 'tson :: tsən', 'mste :: stɝ#', 'oral :: ɔɹəɫ', 'ngto :: ɪŋtə', 'ston :: stən', 'sion :: ɪʒən', 'row# :: ɹoʊ#', '#com :: #kəm', '#rad :: #ɹæd', 'nger :: ɪŋɝ#', 'lman :: ɑɫmə', "n's# :: ənz#"]
# topic 010 found 201 locally superposed terms: ["ton[#,']::ɝtən", 'ton#::[s,ɝ]tən', 'terma::tɝmən', 'ship#::ɝʃɪp#', 'ight::[n,ɹ]aɪt', "ton's::ɹtənz", 'erson::ɝsən#', 'ing#::[ɝ,ʃ]ɪŋ#', 'ers#::ndɝz#', 'ers#::stɝz#', 'terma::tɝmə', 'erma::tɝmən', 'rman::tɝmən', 'ship#::ɝʃɪp', "n's#::ɹtənz", "n's#::tənz#", 'rman::ɝmən#', "rton'::tənz", 'beach::#bit', 'ingt::ŋtən#', '#home::#hoʊ', 'land#::ɫənd', '#bra::#bɹæn', 'mcgu::#məɡ', 'erma::tɝmə', 'erma::ɝmən', "ton'::stən", 'life::#ɫaɪ', 'ger#::ɪŋɝ#', 'ngto::ɪŋtə', '#bra::#bɹæ', 'nd::[s,ɫ]ənd', 'mtra::tɹæk', 'on::[s,ʃ]ən#', 'term::tɝmə', 'ski#::nski', 'try#::stɹi', '::ɝ[m,t]ən#', '::ɝ[s,t]ən#', '::[ŋ,ɝ]tən#', '#stam::st', '::ɝ[m,s]ən#', 'son::tsən', '::[ɝ,ɹ]tən', "ton[#,']::", 'ers[#,o]::', 'term::tɝ', '::[f,t]ɝz#', '::[t,ɝ]sən', '::[ŋ,ɹ]tən', 'ing[#,t]::', '::[s,ŋ]tən', '::[s,ɫ]ənd', '::[v,ʃ]ən#', '::[t,ʃ]ən#', '::[ɑ,ɛ]tə#', '::[s,ɹ]tən', '::[s,v]ən#', '::[s,t]ən#', 'and[#,e]::', '::[t,v]ən#', '#::ɝtən', '::ɝtən#', '::stɝz#', '::tənz#', 'ande::#', '::inəs#', 'tra::tɹ', "ton's::", '::#æmtɹ', 'ton#::', 'ers#::', 'term::', 'ster::', '::tənz', '::ŋtən', '::stən', 'nter::', 'and#::', '::ɝsən', 'ming::', 'son#::', '::tɝmə', '::ɝmən', 'ingt::', '::ɪŋtə', '::tsən', 'ing#::', 'mtra::', 'ngto::', "ton'::", '::ɹtən', "n's#::", 'amtr::', 'ande::', '::ənz#', 'on#::', '#::st', '::stɝ', 'ter::', '::stɑ', 'err::', 'er::#', "'s#::", '::tən', '#::tə', 'ass::', 'n::#m', 'man::', 'h::#b', 'and::', 'er::ɪ', '#::ɪŋ', 'ra::#', '::sən', 'ion::', 'on::s', 's#::ə', 'tra::', 'om::#', '#::fɝ', 'd#::f', '#::ɝ', 'n#::', '::#b', 'ck::', 's#::', '::nd', '#::n', '#::s', '::st', '::tɝ', 'a::t', 'r::#', 'er::', 'r::t', 'ta::', 'e#::', '#::ɹ', '::fɛ', '::#m', 'u::#', 'y#::', 'i::#', '::#ɹ', 's::#', '::#k', '::tə', '::#ɛ', '::#h', 'nd::', 'd::#', 'in::', '::ɪn', '#::ɫ', 'tr::', 'n::ɝ', '#::ɪ', '::ɪŋ', '::#s', 'a::#', 'ra::', 'g#::', 'i#::', 'on::', '#::ɑ', 'a#::', 'e::#', 'il::', 'd#::', '::tɹ', '#::f', '#::', '::ɝ', '::#', 'k::', '::n', '::s', 'a::', '::t', 'r::', '::ɹ', '::f', '::æ', 'i::', 't::', 's::', 'n::', 'd::', 'o::', '::b', '::ɪ', '::ɫ', 'm::', 'e::', '::ʃ', '::ɑ', 'l::', '::m', '::ə', '::']
# ...
# topic 086 found 187 locally superposed terms: ['#fla[n,s]::#fɫæ', 'ton#::[s,ɝ]tən#', 'erman::[d,t]ɝmə', 'art[#,w]::hɑɹt', '#barb::#bɑɹb', 'arb::#[b,k]ɑɹb', 'ton#::[s,ɹ]tən', 'rton::[ɝ,ɹ]tən', 'tch#::[æ,ɪ]tʃ#', 'ing#::[t,ɪ]ɪŋ#', 'ing[#,s]::əɫɪŋ', 'ing#::[t,v]ɪŋ#', 'maste::#mæst', 'erma::[d,t]ɝmə', 'erman::tɝmən', 'ing::[v,ɪ]ɪŋ#', 'ton#::stən#', 'erman::dɝmə', 'derma::dɝmə', 'aster::mæst', '#bran::#bɹæ', 'erm::[d,t]ɝmə', 'man::[t,ɝ]mən', 'rman::ɝmən#', 'art#::ɪnhɑ', 'lman::ɑɫmə', 'ma::[k,ɫ]mən', 'wild::aɪɫd', 'ood#::wʊd#', 'orn#::bɔɹn', 'hand::#hæn', 'ess#::tɫəs', 'tran::#tɹæ', 'ton::ɝtən#', 'man::tɝmən', 'o#::[ɫ,ɹ]oʊ#', 'o#::[n,ɹ]oʊ#', 'mcgu::məɡɝ', 'n::ɝ[m,t]ən#', 'nger::ɪŋɝ#', 'd#::[f,t]ɝd#', 'o#::[n,ɫ]oʊ#', 'ton::ɹtən', 'n::[m,t]ən#', 'man::tmən', 's#::stɝz#', 'ro#::ɑɹoʊ', 'art[#,w]::', '::[p,t]ɹeɪ', '::[t,ɫ]mən', '::[ɝ,ɫ]mən', '::[h,v]ænd', 'ing[e,s]::', 'ing[#,s]::', 'ing[#,e]::', 'der[#,m]::', '::[k,t]mən', '::[k,ɝ]mən', '::[#,ɪ]sən', 'ste[p,r]::', '::[d,t]ɝmə', '#wild::', 'inge::ɪ', '#::ɹaɪt', '::#mæst', '#tran::', 'hart#::', '::tɝmən', 'tra::tɹ', '::#ɫaɪ', 'art#::', 'land::', 'term::', 'artw::', '::ɫmən', '::ɑɡəɫ', '::#məɡ', 'ing::ɪ', 'ings::', 'ing#::', 'ed#::t', 'ess#::', 'der#::', 'rans::', 'ran::#', 'ande::', '::#waɪ', '::kmən', 'ged#::', 'rman::', 'step::', '::bɹæn', 'wild::', 's#::st', '::dɝmə', 'inge::', 'nder::', 'derm::', '#::aɪ', 'an::#', 'ter::', '#::ɑɹ', 'man::', 'arb::', '#::st', 'on#::', 'ed#::', 's#::t', 'ar::#', 'and::', 'el::#', 'ing::', 'ess::', '#::tɝ', 'er::#', '::#pɛ', 'e::#', '#::ɪ', 't#::', '::aɪ', 'e#::', 'an::', 'n::#', '::#f', 'er::', '::æt', '::ɑɹ', '::#b', 'a#::', 'ma::', '#::ɑ', '#::ɫ', '::ɫɪ', '::#w', 't::#', 'r::#', 'n#::', '#::w', 'd#::', '::#m', 'k::#', '::st', 's#::', '#::t', '::tə', 's::#', '#::ɹ', 'a::#', '::#t', '::ɪd', 'n::t', 'ra::', 'd::#', '::tɝ', '::tɹ', '::mə', '::#s', 'o#::', '::#k', '::#', 'e::', '#::', '::ɪ', 'n::', 'r::', '::æ', '::ɑ', 't::', '::ɫ', 'i::', 'a::', 'd::', 'l::', '::ɹ', '::b', 'h::', 'g::', '::h', '::ɝ', '::t', 's::', '::d', '::m', '::n', '::v', '::ɡ', '::']
# topic 087 has 120 raw terms: ['derma :: ɝmən#', '#mcgu :: #məɡɝ', 'ters# :: stɝz#', 'light :: #ɫaɪt', "ton's :: ɹtənz", 'erson :: ɝsən#', 'kman# :: kmən#', 'rman# :: ɝmən#', 'lland :: ɫənd#', '#mast :: #mæst', 'ider :: aɪdɝ#', 'idge# :: ɪdʒ#', 'ship# :: ʃɪp#', 'come# :: kəm#', '#mel :: #mɛɫə', 'gton :: ŋtən#', 'ight# :: aɪt#', 'ight :: #ɫaɪt', 'ering :: ɝɪŋ#', 'eson# :: sən#', 'stock :: stɑk', 'ande :: #vænd', 'kman# :: kmən', 'stry :: stɹi#', 'lland :: ɫənd', 'aker# :: eɪkɝ', 'ters# :: tɝz#', 'ligh :: #ɫaɪt', 'hart :: hɑɹt#', 'mster :: stɝ#', 'ness# :: dnəs', 'less# :: ɫəs#', 'head# :: hɛd#', '#amtr :: tɹæk', 'ider# :: aɪdɝ', "d's# :: ɑɹdz#", '#tot :: #toʊt', '#mcd :: #məkd', 'and# :: ɫənd#', 'etta# :: ɛtə#', '#amt :: mtɹæk', 'mast :: mæstɝ', 'beach :: #bit', 'erma :: tɝmən', 'water :: wɔtɝ', 'each :: #bitʃ', 'aste :: mæstɝ', 'light :: #ɫaɪ', '#swin :: #swɪ', 'kman :: kmən#', 'mtra :: mtɹæk', 'ning :: ənɪŋ#', 'mtra :: æmtɹæ', 'eson# :: ɪsən', 'aker# :: ɪkɝ#', '#sca :: #skɛɹ', '#weis :: #waɪ', 'inski :: ɪnsk', 'ord# :: fɝd#', '#lan :: ɫænd', "m's# :: əmz#", '#mar :: mɑɹk', '#dow :: #daʊ', 'ing# :: dɪŋ#', 'town :: taʊn', '#hor :: #hɔɹ', 'lers :: əɫɝz', 'ble# :: bəɫ#', 'iff# :: ɫɪf#', '#pom :: #pɑm', '#rem :: #ɹɛm', 'ata# :: ɑtə#', 'erg# :: bɝɡ#', 'wild :: aɪɫd', 'gle# :: ɡəɫ#', 'ites :: aɪts', 'hip# :: ʃɪp#', '#bro :: #bɹɑ', 'erto :: tən#', '#cra :: #kɹæ', 'wate :: wɔtɝ', 'ton# :: tɑn#', 'gert :: ɡɝt#', '#bea :: bitʃ', 'ieri :: ɪɹi#', '#bor :: #bɔɹ', '#pol :: #pɑɫ', 'kle# :: kəɫ#', 'ota# :: oʊtə', 'try# :: stɹi', 'elin :: ɫɪn#', 'boat :: boʊt', 'ling :: əɫɪŋ', '#lar :: #ɫɑɹ', 'erso :: sən#', 'stoc :: stɑk', 'ers# :: ɫɝz#', 'ina# :: ɪnə#', 'man# :: ɝmən', 'ano# :: noʊ#', 'ngto :: ŋtən', 'ning :: ənɪŋ', 'ight :: naɪt', 'ell# :: eɪɫ#', 'ons# :: ənz#', 'swin :: #swɪ', 'gged :: æɡd#', 'son# :: ɫsən', 'ess# :: inəs', 'life :: ɫaɪf', '#und :: #ənd', 'ligh :: #ɫaɪ', 'stam :: #stæ', '#har :: #hɑɹ', "ton' :: ənz#", '#sil :: #sɪɫ', '#sna :: #snæ', '#sun :: #sən', 'del# :: dəɫ#', 'ansk :: ski#']
# topic 087 found 194 locally superposed terms: ['man#::[k,ɝ]mən#', 'ing#::[d,ɝ]ɪŋ#', 'man#::[k,ɝ]mən', 'light::#ɫaɪt', 'ess#::[d,i]nəs', 'ters#::stɝz#', '#amtr::mtɹæk', 'erson::ɝsən#', 'ers#::[t,ɫ]ɝz#', 'kman#::kmən#', 'son#::[ɝ,ɪ]sən', 'son#::[ɪ,ɫ]sən', 'son#::[ɝ,ɫ]sən', 'ider#::aɪdɝ', 'ight#::naɪt', 'ight::#ɫaɪt', '#po[l,m]::#pɑ', 'ta#::[ɑ,ɛ]tə#', 'son#::ɝsən#', 'eson#::ɪsən', 'stock::stɑk', 'kman#::kmən', 'lland::ɫənd', 'light::#ɫaɪ', 'mtra::mtɹæk', 'and#::ɫənd#', 'aste::mæstɝ', 'mast::#mæst', 'erma::tɝmən', 'aste::#mæst', 'aker#::eɪkɝ', 'le#::[b,ɡ]əɫ#', 'le#::[b,k]əɫ#', 'water::wɔtɝ', 'mtra::æmtɹæ', 'le#::[k,ɡ]əɫ#', 'ight::#ɫaɪ', 'ers#::əɫɝz', 'son#::ɫsən', 'and#::ɫənd', 'nd::[#,ɫ]ənd', 'ligh::#ɫaɪ', 'each::#bit', 'man#::ɝmən', 'swin::#swɪ', 'ning::ənɪŋ', 'hip#::ʃɪp#', 'gton::ŋtən', 'hart::#hɑɹ', 'try#::stɹi', 'o::[s,t]ən#', 'ers[#,o]::s', '::[k,ɝ]mən#', '::ɝ[m,s]ən#', '#::[b,d]əɫ#', '#::[d,ɡ]əɫ#', '#::[d,k]əɫ#', 'n::[#,ɝ]sən', '#la[n,r]::', '::[s,t]ən#', '::[k,ɝ]mən', 'to::ŋtən', "ton[#,']::", 'and[#,e]::', '::[#,ɫ]ənd', 'ers[#,o]::', '::[#,ɪ]sən', '::[ŋ,ɹ]tən', '::[#,ɫ]sən', 'land::ɫ', 'ight#::', '::ŋtən#', '::#bitʃ', '::mtɹæk', '::æmtɹæ', '::tɝmən', '::ɝmən#', "ton's::", 'ing#::', 'ight::', '::#ɫaɪ', 'ers#::', 'erso::', '::sən#', '::#sən', '::naɪt', 'ande::', 'erto::', '::ɹtən', 'ton#::', '::#bit', 'ster::', 'ess#::', 'ling::', 'mtra::', '::ɫsən', '::ɪsən', '::ənz#', 'ing::ə', 'nski::', 'e#::kə', '::ɝmən', '::boʊt', "ton'::", "'s#::", 's#::ə', '::aɪt', '#::aɪ', 'ing::', 'ta#::', 'on#::', 'or::#', '::stɝ', 'ter::', '#::st', '#::ɫə', 's#::ɫ', 'n::#s', 'er#::', 'ar::#', 'r::#h', '#::eɪ', '::#mə', 'a::#s', '::aɪ', 'er::', 'd#::', 'n::ɫ', 'an::', '::#m', 'l::#', 's#::', 'g#::', '#::d', '::#ɫ', 't::#', '::əɫ', 'm::#', '#::ɑ', 'a#::', 'n#::', '#::s', '::st', 'k::s', '#::k', '::ɫə', '::#b', 'ra::', 'a::#', '#::t', 'h::#', 'r::#', '::ɫɪ', 'in::', '#::ɫ', 't::m', '::tɝ', 'te::', '::#s', '::ən', '#::ɪ', 'i::ɪ', '::ɪn', 'l#::', 'e#::', 'ar::', '#::b', 'd::#', 'rt::', 'on::', 'r::', '#::', 'n::', '::ɫ', '::#', '::ə', 't::', 's::', '::ɝ', 'd::', '::s', 'o::', '::t', 'a::', '::b', '::h', '::m', 'e::', '::n', '::æ', '::ɪ', '::k', '::ɡ', '::']
# topic 088 has 120 raw terms: ['derma :: dɝmən', '#bran :: #bɹæn', 'stry# :: stɹi#', 'ches# :: tʃəz#', '#over :: #oʊvɝ', 'beach :: #bitʃ', 'erman :: ɝmən#', 'lings :: ɪŋz#', 'hart# :: ɑɹt#', '#pre :: #pɹeɪ', 'eson :: ɪsən#', 'nski :: nski#', 'erton :: tən#', '#fore :: #fɔɹ', 'idge# :: ɹɪdʒ', '#carb :: #kɑɹ', 'son# :: ɝsən#', '#dal :: #deɪɫ', 'ness# :: inəs', 'ings :: ɫɪŋz#', 'ches :: tʃəz#', 'amtr :: #æmtɹ', '#fran :: #fɹæ', '#weis :: #waɪ', '#gol :: #ɡoʊɫ', 'rson# :: ɝsən', 'ppert :: pɝt#', 'mela :: #mɛɫə', '#cra :: #kɹeɪ', "on's :: tənz#", '#stor :: #stɔ', 'inger :: ɪŋɝ#', 'hing# :: ʃɪŋ#', 'terma :: tɝmə', '#bar :: #bɑɹb', 'llan :: ɫənd#', 'ancy :: ænsi#', '#amtr :: æmtɹ', 'aker :: eɪkɝ#', 'guard :: ɡɑɹd', '#tran :: tɹæn', 'oted# :: tɪd#', '#han :: #hænd', 'ges# :: dʒəz#', '#mcgu :: #məɡ', '#hand :: #hæn', "ton' :: tənz#", '#amt :: mtɹæk', '#star :: stɑɹ', 'ight :: ɫaɪt', '#van :: vænd', 'der# :: ndɝ#', 'ckma :: kmən', '#bar :: bɑɹb', 'mtra :: æmtɹ', 'ding :: dɪŋ#', 'atte :: ætɝ#', '#dem :: #dɛm', '#hed :: #hɛd', 'ker# :: ɪkɝ#', 'nsky :: nski', 'born :: ɔɹn#', 'barb :: bɑɹb', '#non :: #nɑn', 'llin :: ɪɫɪŋ', 'rand :: ɹænd', 'aste :: æstɝ', 'ggle :: ɡəɫ#', '#ren :: #ɹɛn', 'nds# :: ndz#', '#mar :: mɑɹk', 'ley# :: tɫi#', 'ille :: vɪɫ#', "ard' :: ɑɹdz", '#stu :: #stu', 'ess# :: dnəs', 'red# :: tɝd#', 'eld# :: ɛɫd#', '#mcd :: məkd', '#gar :: #ɡɑɹ', '#pay :: #peɪ', '#sar :: #sɑɹ', '#rai :: #ɹeɪ', 'der# :: aɪdɝ', '#dor :: #dɔɹ', '#blo :: #bɫɑ', 'atle :: tɫi#', 'ites :: aɪts', 'ics# :: ɪks#', '#amt :: mtɹæ', 'sand :: #sæn', '#col :: #koʊ', 'ying :: ɪɪŋ#', 'nzo# :: nzoʊ', 'ble# :: bəɫ#', '#ski :: #skɪ', 'dget :: dʒɪt', '#rep :: #ɹip', '#spi :: #spɪ', 'insk :: ɪnsk', 'ines :: inəs', 'ling :: ɫɪŋ#', 'ches :: ʃəz#', 'toma :: #toʊ', 'flan :: #fɫæ', '#lan :: ɫænd', '#por :: #pɔɹ', 'erin :: ɝɪŋ#', 'elli :: ɛɫi#', 'less :: tɫəs', 'rson :: ɝsən', 'hart :: hɑɹt', '#ham :: #hæm', '#roc :: #ɹɑk', '#sca :: skɛɹ', 'mark :: mɑɹk', 'mast :: mæst', 'rman :: dɝmə', '#war :: #wɔɹ', 'ess# :: inəs']
# topic 088 found 182 locally superposed terms: ['son#::[ɝ,ɪ]sən#', 'son#::[ɝ,ɪ]sən', 'nsk[i,y]::nski', 'ess#::[d,i]nəs', 'erma::[d,t]ɝmə', 'erman::dɝmən', 'ing#::[ɫ,ʃ]ɪŋ#', 'ing#::[d,ʃ]ɪŋ#', 'ing#::[ɪ,ʃ]ɪŋ#', 'rman::[d,t]ɝmə', 'ches#::tʃəz#', 'ings::ɫɪŋz#', 'son::[ɝ,ɪ]sən', 'ker#::eɪkɝ#', 'rson#::ɝsən', "on's::tənz#", 'amtr::#æmtɹ', '#amtr::æmtɹ', 'ing::[d,ɫ]ɪŋ#', 'ing::[ɪ,ɫ]ɪŋ#', '#ha[m,n]::#hæ', '#hand::#hæn', 'hart#::hɑɹt', 'mtra::#æmtɹ', '#bar::#bɑɹb', 'barb::#bɑɹb', 'ing::[d,ɪ]ɪŋ#', 'ches::tʃəz#', 'erman::tɝmə', 'an::[v,ɫ]ænd', 'nski::ɪnsk', 'rand::tɹæn', 'ess#::inəs', "ard'::ɡɑɹd", 'son#::ɝsən', 'rman::dɝmə', '#re[n,p]::#ɹ', 'nsky::ɪnsk', 'mtra::æmtɹ', 'ling::ɪɫɪŋ', 'mark::mɑɹk', '#amt::mtɹæ', 'aste::mæst', 'barb::bɑɹb', '::#[k,p]ɹeɪ', "ton'::tən", 'ings::ɫɪŋ', '#st[a,o]r::', '::ɝ[m,s]ən#', 'ing[#,s]::', '::[v,ɹ]ænd', '::[k,ɝ]mən', '::[ɫ,ɹ]ænd', '::[b,ɡ]əɫ#', '::[t,ɛ]ɫi#', 'dge[#,t]::', '::[ɝ,ɫ]ɪŋ#', '::[d,i]nəs', '::[ɝ,ʃ]ɪŋ#', '::[d,ɝ]ɪŋ#', '::[ɝ,ɪ]ɪŋ#', 'ings::ɪ', 'lings::', '::#pɹeɪ', '::#kɹeɪ', 'ings::', 'rand::', '::inəs', 'ess#::', '::ɪɫɪŋ', '::tɫi#', 'ed#::t', '::#ɡɑɹ', 'and::#', 'tran::', '::mtɹæ', 'an::#f', '::ɫaɪt', '::æmtɹ', 'llin::', 'amtr::', 'der#::', 'ran::#', 'lan::ɫ', 're::#', 'ski::', '::tən', 'te::æ', 'arb::', 'd::#h', 'er#::', '#::ɪk', 'and::', 'ol::#', 'ar::#', 'r::#s', '::#st', 'or::#', 'i::#s', 'ran::', 'an::#', 'lan::', '::#hæ', 's#::d', 'es#::', '#::nd', '::ɪŋ', 'an::', 'ma::', '::#p', 'on::', 'n::ɪ', 'n::t', '::#k', 'd::#', '::#h', 'n::#', 'le::', '::#d', 'l::#', 's#::', '#::t', 'y#::', '::tɫ', '::ɑɹ', '::#ɡ', 'd#::', '::tɝ', 'ar::', 'r::#', '::#s', 'rt::', 'a::#', '::#m', '::#b', 's::t', '#::n', 'e#::', 'i::#', '::dʒ', '::#ɹ', '::#f', 'n::ɝ', 'm::#', 'u::#', '::#w', '::st', 'ra::', 'in::', 'es::', '::aɪ', 't::m', 'er::', '::ɛɫ', '::ɪ', 's::', 'n::', '::v', 'a::', 'e::', '::#', '::n', 'i::', '::t', '::æ', 'd::', '#::', '::ɹ', '::ɡ', '::ɫ', "'::", '::ɝ', '::d', 'r::', 't::', '::b', 'y::', 'k::', '::s', '::m', '::ʃ', '::']
# topic 089 has 120 raw terms: ['ders# :: ndɝz#', 'lden# :: ɫdən#', '#hand :: #hænd', 'ites# :: aɪts#', 'ding# :: ɪdɪŋ#', '#flan :: #fɫæn', 'amtra :: æmtɹæ', 'tson :: tsən#', 'owski :: ski#', 'ander :: ndɝ#', 'inger :: ɪŋɝ#', '#miss :: #mɪs', 'mste :: mstɝ#', '#pro :: #pɹoʊ', '#wild :: aɪɫd', 'ding :: ɪdɪŋ#', 'art# :: nhɑɹt', 'water :: wɔtɝ', 'lman# :: mən#', 'tman# :: tmən', 'ancy :: ænsi#', 'agged :: æɡd#', 'lden# :: dən#', 'come# :: kəm#', 'nders :: ændɝ', 'life :: #ɫaɪf', "ard' :: ɑɹdz#", '#bric :: #bɹɪ', '#beac :: bitʃ', 'gton# :: tən#', '#galo :: #ɡəɫ', 'pert# :: pɝt#', 'ship# :: ɝʃɪp', 'erman :: dɝmə', 'amtra :: æmtɹ', 'ering :: ɝɪŋ#', 'ridge :: ɪdʒ#', '#toma :: #toʊ', 'erto :: ɝtən#', '#cass :: #kæs', 'ving# :: vɪŋ#', 'amtra :: tɹæk', 'sky# :: nski#', '#sund :: sənd', 'erton :: tən#', 'ling# :: əɫɪŋ', 'wick :: wɪk#', 'ello :: ɛɫoʊ', 'man# :: tmən', '#non :: nɑnf', 'eson :: sən#', 'ight :: aɪts', 'ing# :: sɪŋ#', '#bud :: #bəd', 'ses# :: sɪz#', 'erma :: ɝmən', 'one# :: oʊni', '#whi :: #hwɪ', 'ing# :: ɪdɪŋ', 'lin# :: ɪɫɪn', 'rton :: tənz', 'her# :: tʃɝ#', 'ngle :: ŋɡəɫ', '#tra :: tɹæn', '#gen :: #dʒɛ', '#pet :: #pɛt', '#com :: #kəm', 'head :: hɛd#', 'ing# :: pɪŋ#', 'barb :: #bɑɹ', 'ona# :: oʊnə', '#med :: #mɛd', 'eman :: mən#', "on's :: tənz", 'yer# :: aɪɝ#', 'berg :: bɝɡ#', 'ters :: stɝz', 'nds# :: əndz', '#mat :: #mæθ', 'hes# :: ʃəz#', 'chey :: tʃi#', '#tot :: toʊt', 'erto :: ɝtən', '#mel :: mɛɫə', 'tal# :: təɫ#', '#car :: #kɛɹ', 'lson :: sən#', 'down :: #daʊ', '#mai :: #meɪ', 'ting :: tɪŋ#', '#dis :: dɪsk', 'ing# :: nɪŋ#', 'hart :: ɪnhɑ', 'road :: ɹoʊd', 'ard# :: ɑɹd#', 'life :: #ɫaɪ', 'ing# :: əɫɪŋ', 'lass :: kɫæs', '#kos :: #koʊ', '#lin :: #ɫɪn', 'lect :: ɫɛkt', 'walk :: #wɔk', 'cked :: ɑkt#', '#mcn :: məkn', 'nder :: dɝz#', '#van :: #væn', 'anno :: ænən', 'mtra :: mtɹæ', 'tman :: mən#', 'llo# :: ɫoʊ#', 'ansk :: nski', 'oggl :: ɑɡəɫ', 'mast :: æstɝ', 'ggle :: ɑɡəɫ', 'ling :: ɪŋz#', 'star :: #stɑ', '#car :: #kɑɹ', 'iff# :: ɫɪf#', 'tner :: tnɝ#', '#gar :: #ɡɑɹ']
# topic 089 found 189 locally superposed terms: ['lden#::ɫdən#', 'lin#::[#,ɪ]ɫɪn', 'ing#::[s,t]ɪŋ#', 'ing#::[p,t]ɪŋ#', 'ing#::[n,t]ɪŋ#', 'ing#::[t,v]ɪŋ#', 'ing#::[n,s]ɪŋ#', 'ing#::[n,p]ɪŋ#', 'ing#::[n,ɝ]ɪŋ#', 'ing#::[n,v]ɪŋ#', 'ing#::[s,ɝ]ɪŋ#', 'ing#::[p,ɝ]ɪŋ#', 'ing#::[v,ɝ]ɪŋ#', 'erton::ɝtən#', 'ing#::[s,v]ɪŋ#', 'ing#::[p,v]ɪŋ#', 'ing#::[p,s]ɪŋ#', 'ding#::ɪdɪŋ#', 'ders#::ændɝ', 'erman::dɝmə', 'gle::[ŋ,ɑ]ɡəɫ', 'tman#::tmən', 'nders::ændɝ', 'ing::[t,ɝ]ɪŋ#', "ard[#,']::ɑɹd", 'amtra::æmtɹ', 'erton::ɝtən', 'mtra::æmtɹæ', 'son::tsən#', 'ing#::ɪdɪŋ', 'man#::tmən', 'man#::mən#', 'on::[s,t]ən#', 'life::#ɫaɪ', 'ing#::əɫɪŋ', 'rton::ɝtən', 'erto::ɝtən', 'mtra::mtɹæ', 'llo#::ɛɫoʊ', 'n#::[d,m]ən#', 'n#::[d,t]ən#', '#ma[i,t]::#m', 'art#::ɪnhɑ', 'mtra::æmtɹ', 'n#::[m,t]ən#', 'ton#::tən#', 'ggle::ɑɡəɫ', 'on::tsən#', 'lin[#,g]::ɪ', 'n::[m,s]ən#', 'man::mən#', 'n::[m,t]ən#', 'son::sən#', 'ton#::tən', 'rton::tən', 'tra::mtɹæ', '::[m,æ]stɝ', '::[t,ɝ]mən', '::[#,ŋ]ɡəɫ', '::[ŋ,ɑ]ɡəɫ', '::[d,m]ən#', '::[m,t]ən#', '#me[d,l]::', '::[m,s]ən#', '::[d,s]ən#', '::[s,t]ən#', 'ert[#,o]::', 'tra::tɹæ', '::[d,t]ən#', '#car::#k', '::[#,ɑ]ɡəɫ', '::tsən#', '::nski#', '::ndɝz#', 'ing#::ɪ', 'ling#::', 'nders::', '::ɝtən#', 'amtra::', '::tsən', '::nski', '::aɪts', 'ers#::', '::mstɝ', '::ɝmən', '#::oʊn', 'ing#::', 'ters::', '::#kəm', 'man#::', '::æstɝ', '::sənd', '::#toʊ', 'ling::', 'nder::', '::ɝtən', 'ing::ɪ', '::tənz', 'on::t', '::ndɝ', 'er#::', 'n#::t', 'man::', 'n::mə', '#::aɪ', 'ers::', 'es#::', '::sən', 'n::#d', 'ing::', 's::#k', 'an::#', 'ar::#', 'ss::#', 'tra::', '::tən', 'ass::', '#::sɪ', 'rt#::', '#::tə', 'on::', '::aɪ', 's#::', '#::n', 'd::#', '::#b', 'ma::', 'n#::', '#::ɫ', 'e#::', '#::ɪ', '::ɪd', '#::t', '::tʃ', 'er::', '::#p', 't::#', '::#k', 'ad::', 'ed::', 'an::', '#::ə', '::æn', 'n::#', '::#ɫ', '::dɝ', 's::#', '::ɪŋ', 'nd::', 'lo::', '::#m', 'ss::', 'o::#', '::#h', 'i::#', '::tə', '::#ɡ', '::mə', '#::p', '::w', 'k::', '::t', 'n::', '::s', 'i::', '::n', 't::', '#::', '::#', 'd::', 'e::', '::m', 'a::', '::ɝ', '::ɫ', '::ɪ', 'r::', '::æ', 's::', 'y::', 'l::', '::b', 'c::', 'g::', '::ɑ', '::d', 'o::', '::k', '::']
# # Topic-wise term integration for HDP 45 topics via English adj (WN) sp_skippy4gram
