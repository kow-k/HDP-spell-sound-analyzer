# %%
# !pip3 install pyalign
# Out:
# ...
#   Using cached pyalign-0.4.4.tar.gz (50 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pybind11-2.6.2-py2.py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached cached_property-1.5.2-py2.py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached py_cpuinfo-8.0.0-py3-none-any.whl
# ...
#   Using cached pymorton-1.0.5-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached PyYAML-6.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Using cached pymorton-1.0.5-py2.py3-none-any.whl (4.4 kB)
# Using cached PyYAML-6.0-cp310-cp310-macosx_11_0_arm64.whl (173 kB)
# Using cached pybind11-2.6.2-py2.py3-none-any.whl (191 kB)
# Using cached cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyalign (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [56 lines of output]
# ...

# %%
import gensim
dir(gensim)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_matutils',
#  'corpora',
#  'interfaces',
#  'logger',
#  'logging',
#  'matutils',
#  'models',
#  'parsing',
#  'similarities',
#  'topic_coherence',
#  'utils']

# %%
import gensim.models as models
dir(models.HdpModel)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adapt_by_suffix',
#  '_apply',
#  '_load_specials',
#  '_save_specials',
#  '_smart_save',
#  'add_lifecycle_event',
#  'doc_e_step',
#  'evaluate_test_corpus',
#  'get_topics',
#  'hdp_to_lda',
#  'inference',
#  'load',
#  'optimal_ordering',
#  'print_topic',
#  'print_topics',
#  'save',
#  'save_options',
#  'save_topics',
#  'show_topic',
#  'show_topics',
#  'suggested_lda_model',
#  'update',
#  'update_chunk',
#  'update_expectations',
#  'update_finished',
#  'update_lambda']
